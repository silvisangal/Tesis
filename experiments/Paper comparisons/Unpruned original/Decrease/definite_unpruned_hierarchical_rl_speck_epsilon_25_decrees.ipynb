# %% [markdown]
# # RL over cLATb for SPECK (ε = 0.25)
#
# Trains a tabular **Q-learning** agent using the **cLATb** structure: `cLATb: { u: { v: { w: bd }}}`.
# - **Reward** = `log₂(|bias|)` (piling-up).
# - **State** = `(u, v)`, **Action** = `w`.
# - **Transition** (SPECK): `u' = ROR(w, α)`, `v' = ROL(v, β) XOR w`.
# - **Exploration**: ε-greedy with **ε = 0.1**.
#
# Works in **Colab** (file upload / Drive), Kaggle, or local Jupyter.

# %%
import sys
import os, gzip, pickle, math, random
from collections import defaultdict
from typing import Dict, Tuple, List, Optional, Iterable

from collections import defaultdict
from typing import Any

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
SEED = 1337
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Auto detect the environment and locate and load the cLAT

# %%
DEFAULT_NAME = "clat_speck.pkl.gz"

ENV = {
    "colab": "google.colab" in sys.modules,
    "kaggle": bool(os.environ.get("KAGGLE_KERNEL_RUN_TYPE")),
    "vscode": bool(os.environ.get("VSCODE_PID")),
}
ENV["jupyter_local"] = not any(ENV.values())

def candidate_paths():
    cands = []
    if "CLAT_PATH" in globals():
        cands.append(globals()["CLAT_PATH"])
    cands += [DEFAULT_NAME, f"./{DEFAULT_NAME}"]
    if ENV["colab"]:
        cands += [f"/content/{DEFAULT_NAME}",
                  f"/content/drive/MyDrive/{DEFAULT_NAME}",
                  f"/content/drive/MyDrive/Tesis/{DEFAULT_NAME}"]
    if ENV["kaggle"]:
        cands += [f"/kaggle/working/{DEFAULT_NAME}", f"/kaggle/input/{DEFAULT_NAME}"]
    return cands

def find_first_existing(paths):
    for p in paths:
        if os.path.exists(p):
            return p
    return None

cands = candidate_paths()
path = find_first_existing(cands)

# Colab: si no aparece, permitir upload o Drive
if not path and ENV["colab"]:
    try:
        from google.colab import files, drive  # type: ignore
        print("File not found. Choose one:")
        print("  a) Upload now (files.upload)")
        print("  b) Mount Drive and use /content/drive/MyDrive/...")
        choice = "a"  # cambia a "b" si prefieres Drive
        if choice.lower() == "a":
            up = files.upload()
            if up:
                path = list(up.keys())[0]
        else:
            drive.mount("/content/drive")
            path = f"/content/drive/MyDrive/{DEFAULT_NAME}"
    except Exception as e:
        print("Upload/Drive not available:", e)

if not path:
    # glob needs to be imported as well
    import glob
    g = glob.glob(f"**/{DEFAULT_NAME}", recursive=True)
    if g: path = g[0]

if not path:
    raise FileNotFoundError("Could not find the cLAT pickle. "
                            "Place 'clat_speck.pkl.gz' next to this notebook or set CLAT_PATH.\n"
                            "Tried:\n" + "\n".join(cands))

print("ENV:", ENV)
print("Using path:", os.path.abspath(path))

# Cargar pickle (fallback de encoding)
try:
    with gzip.open(path, "rb") as f:
        clat_obj = pickle.load(f)
except Exception:
    with gzip.open(path, "rb") as f:
        clat_obj = pickle.load(f, encoding="latin1")

print("Loaded object type:", type(clat_obj))

# Seleccionar payload que contiene 'cLATb'
if isinstance(clat_obj, dict) and "cLATb" in clat_obj:
    payload = clat_obj
elif isinstance(clat_obj, dict) and "payload" in clat_obj and isinstance(clat_obj["payload"], dict) and "cLATb" in clat_obj["payload"]:
    payload = clat_obj["payload"]
else:
    candidate = None
    if isinstance(clat_obj, dict):
        for v in clat_obj.values():
            if isinstance(v, dict) and "cLATb" in v:
                candidate = v; break
    if candidate is None:
        raise KeyError("Could not find 'cLATb' in the loaded pickle. Inspect the structure and adjust.")
    payload = candidate

assert "cLATb" in payload, "Payload does not contain 'cLATb'."
print("Found keys in payload:", list(payload.keys()))
# Out:
# ENV: {'colab': True, 'kaggle': False, 'vscode': False, 'jupyter_local': False}
# Using path: /content/clat_speck.pkl.gz
# Loaded object type: <class 'dict'>
# Found keys in payload: ['m', 'cLATmin', 'cLATN', 'cLATu', 'cLATw', 'cLATb']

# %% [markdown]
# ## SPECK-32 implementation

# %%
class Speck:
    def __init__(self, n_rounds=22, word_size=16, use_key_schedule=True, alpha=7, beta=2, m=4):
        self.n_rounds = int(n_rounds)
        self.word_size = int(word_size)
        self.n_words = 2
        self.n_main_key_words = int(m)
        self.n_round_key_words = 1
        self.use_key_schedule = bool(use_key_schedule)
        self.alpha = int(alpha)
        self.beta  = int(beta)
        self.mask_val = (1 << self.word_size) - 1
        # tipos (compat con np):
        self.main_key_word_dtype = np.uint16 if self.word_size == 16 else np.uint32
        self.round_keys = None  # np.array shape (R,1) con palabras de subllave

    # --- Rotaciones ---
    def rol(self, x, r):
        n = self.word_size
        return ((x << r) & ((1 << n) - 1)) | (x >> (n - r))

    def ror(self, x, r):
        n = self.word_size
        return (x >> r) | ((x << (self.word_size - r)) & ((1 << self.word_size) - 1))

    # --- Paridad ---
    @staticmethod
    def parity(x: int) -> int:
        return int(x).bit_count() & 1

    # ============ Ronda ============
    def encrypt_one_round(self, p, k, rc=None):
        """Una ronda: (x,y) -> (x',y'). k es [kw] o (kw,)."""
        x, y = int(p[0]), int(p[1])
        x = self.ror(x, self.alpha)
        x = (x + y) & self.mask_val
        x = x ^ int(k[0])
        y = self.rol(y, self.beta)
        y = y ^ x
        return x, y

    def decrypt_one_round(self, c, k, rc=None):
        """Inversa de una ronda: (x',y') -> (x,y)."""
        x, y = int(c[0]), int(c[1])
        y = y ^ x
        y = self.ror(y, self.beta)
        x = x ^ int(k[0])
        x = (x - y) & self.mask_val
        x = self.rol(x, self.alpha)
        return x, y

    # ============ Full/Reducido ============
    def encrypt(self, plaintext, rounds=None, key=None, trace=False):
        R = self.n_rounds if rounds is None else int(rounds)
        x, y = int(plaintext[0]), int(plaintext[1])
        rk = self.key_schedule(key) if (key is not None) else self.round_keys
        if rk is None:
            raise ValueError("round_keys no inicializadas. Llama key_schedule(key) o pasa key=")
        out = [(x, y)] if trace else None
        for r in range(R):
            x, y = self.encrypt_one_round((x, y), rk[r])
            if trace:
                out.append((x, y))
        return out if trace else (x, y)

    def decrypt(self, ciphertext, rounds=None, key=None, trace=False):
        R = self.n_rounds if rounds is None else int(rounds)
        x, y = int(ciphertext[0]), int(ciphertext[1])
        rk = self.key_schedule(key) if (key is not None) else self.round_keys
        if rk is None:
            raise ValueError("round_keys no inicializadas. Llama key_schedule(key) o pasa key=")
        rk = rk[:R]
        out = [(x, y)] if trace else None
        for r in range(R - 1, -1, -1):
            x, y = self.decrypt_one_round((x, y), rk[r])
            if trace:
                out.append((x, y))
        return out if trace else (x, y)

    # ============ Puntos internos última ronda ============
    def partial_decrypt_last_round(self, C, k_r, stop_at="before_add"):
        """
        Invierte selectivamente la última ronda sobre C=(x',y') usando k_r=[kw].
        stop_at:
          - "after_xor_y"     -> (x', y^)
          - "after_ror_beta"  -> (x', y~~)
          - "after_xor_k"     -> (x^, y~~)
          - "before_add"      -> (x~~, y~~)
          - "after_rol_alpha" -> (x, y) original antes de la última ronda
        """
        x1, y1 = int(C[0]), int(C[1])
        # y = y ^ x
        y = y1 ^ x1
        if stop_at == "after_xor_y":
            return x1, y
        # y = ROR(y, beta)
        y = self.ror(y, self.beta)
        if stop_at == "after_ror_beta":
            return x1, y
        # x = x ^ k
        x = x1 ^ int(k_r[0])
        if stop_at == "after_xor_k":
            return x, y
        # x = (x - y)
        x = (x - y) & self.mask_val
        if stop_at == "before_add":
            return x, y
        # x = ROL(x, alpha)
        x = self.rol(x, self.alpha)
        if stop_at == "after_rol_alpha":
            return x, y
        raise ValueError(f"stop_at desconocido: {stop_at}")

    # ============ Key schedule ============
    def key_schedule(self, key):
        """
        Devuelve np.array shape (n_rounds, 1) con las subllaves.
        'key' como np.array shape (m,1) o lista de m palabras.
        """
        if key is None:
            return self.round_keys
        if isinstance(key, (list, tuple)):
            key = np.array(key, dtype=self.main_key_word_dtype)[:, np.newaxis]
        assert key.shape[0] == self.n_main_key_words, "m (número de palabras de clave) no coincide"
        ks = [0 for _ in range(self.n_rounds)]
        ks[0] = int(key[len(key)-1][0])  # última palabra como k0
        L = list(reversed([int(key[i][0]) for i in range(len(key)-1)]))  # resto invertidas
        for i in range(self.n_rounds - 1):
            L[i % (len(L))], ks[i+1] = self.encrypt_one_round((L[i % len(L)], ks[i]), [i])
        self.round_keys = np.array(ks, dtype=self.main_key_word_dtype)[:, np.newaxis]
        return self.round_keys

    # ============ Correlación exacta de UNA suma (DP de carry) ============
    @staticmethod
    def _corr_addition(a_mask, b_mask, g_mask, n):
        # correlación exacta en [-1,1] para <a,x> ⊕ <b,y> ⊕ <g, x+y>
        A = [(a_mask>>i)&1 for i in range(n)]
        B = [(b_mask>>i)&1 for i in range(n)]
        G = [(g_mask>>i)&1 for i in range(n)]
        DP0, DP1 = 1, 0  # carry_in = 0/1
        for i in range(n):
            nDP0 = nDP1 = 0
            for cin in (0,1):
                base = DP0 if cin == 0 else DP1
                if base == 0:
                    continue
                for x in (0,1):
                    for y in (0,1):
                        cout = (x & y) | (x & cin) | (y & cin)
                        e = ((A[i]^G[i]) & x) ^ ((B[i]^G[i]) & y) ^ (G[i] & cin)
                        if cout == 0:
                            nDP0 += base if e == 0 else -base
                        else:
                            nDP1 += base if e == 0 else -base
            DP0, DP1 = nDP0, nDP1
        return (DP0 + DP1) / (2**(2*n))

    def corr_one_round_masks(self, ax, ay, gx, gy_prime=0):
        """
        Correlación de 1 ronda con máscaras (teórica):
        ax, ay: máscaras de entrada; gx: máscara en x' (XOR k no cambia corr);
        gy_prime: máscara en y' (opcional).
        """
        n = self.word_size
        a_for_adder = self.rol(ax, self.alpha)
        b_for_adder = ay ^ self.ror(gy_prime, self.beta)
        g_for_adder = gx
        return self._corr_addition(a_for_adder, b_for_adder, g_for_adder, n)

    # ===================================================
    #  (1) Herramientas manuales para triples (u,v,w)
    # ===================================================

    def corr_weight_add(self, u, v, w):
        """
        Devuelve Cw (entero) si (u,v,w) es válida para la suma n-bit; None si no lo es.
        Filtro de validez usa máscara Z (bits con acarreo).
        """
        n = self.word_size
        A = u ^ v
        B = u ^ w
        C = u ^ v ^ w
        cw = 0
        Z  = 0
        carry = 0
        for i in range(n):  # LSB→MSB
            cbit = (C >> i) & 1
            carry = (cbit + carry) & 1
            if carry:
                cw += 1
                Z |= (1 << i)
        if (A & ~Z) != 0:
            return None
        if (B & ~Z) != 0:
            return None
        return cw

    def next_round_masks(self, GX_i, GY_i, w):
        """
        Dadas GX_i, GY_i y elección de w = GX_{i+1}, produce:
          triple=(u,v,w)  y  siguiente estado (GX_{i+1}, GY_{i+1}).
        Reglas SPECK:
          u = ROR(GX_i, alpha),  v = GY_i,
          GY_{i+1} = ROL(GY_i, beta) ^ GX_{i+1}.
        """
        u = self.ror(GX_i, self.alpha)
        v = GY_i
        GX_ip1 = w
        GY_ip1 = self.rol(GY_i, self.beta) ^ GX_ip1
        return (u, v, GX_ip1), (GX_ip1, GY_ip1)

    def trail_weight(self, triples):
        total = 0
        for (u, v, w) in triples:
            cw = self.corr_weight_add(u, v, w)
            if cw is None:
                return None
            total += cw
        return total  # |corr| = 2^{-total}

    def greedy_trail(self, GX0, GY0, rounds=6, force_w_last=None, allow_trivial=False,
                 consider_three_bits_if_empty=False):
      """
      Greedy simple pero EXHAUSTIVO en 1–2 bits por ronda.
      - force_w_last: fija w en la última ronda (útil para anclar un gx).
      - allow_trivial: permite u=v=w (Cw=0). Déjalo False salvo diagnóstico.
      - consider_three_bits_if_empty: si no hay ningún 1–2 bits válido, prueba 3 bits.
      Devuelve (triples, GX_list, GY_list, Cw_total) o (None, GX, GY, None) si falla.
      """
      n = self.word_size
      M = self.mask_val
      GX = [0] * (rounds + 1)
      GY = [0] * (rounds + 1)
      GX[0], GY[0] = (int(GX0) & M), (int(GY0) & M)

      triples = []
      total_cw = 0

      for r in range(rounds):
          u = self.ror(GX[r], self.alpha) & M
          v = GY[r] & M

          # Construye lista completa de 1–2 bits
          cand_ws = []
          for i in range(n):
              cand_ws.append((1 << i) & M)
          for i in range(n):
              for j in range(i+1, n):
                  cand_ws.append(((1 << i) | (1 << j)) & M)

          # Si es la última ronda y se pide ancla, solo ese w
          if (force_w_last is not None) and (r == rounds - 1):
              cand_ws = [int(force_w_last) & M]

          best = None
          best_cw = None

          for w in cand_ws:
              triple = (u, v, w)
              cw = self.corr_weight_add(*triple)
              if cw is None:
                  continue
              if (not allow_trivial) and (u == v == w):
                  continue
              if (best_cw is None) or (cw < best_cw):
                  best_cw = cw
                  best = (triple, w)

          # Si no hubo ningún 1–2 bits válido, intenta 3 bits (opcional)
          if (best is None) and consider_three_bits_if_empty:
              for i in range(n):
                  for j in range(i+1, n):
                      for k in range(j+1, n):
                          w = ((1<<i)|(1<<j)|(1<<k)) & M
                          triple = (u, v, w)
                          cw = self.corr_weight_add(*triple)
                          if cw is None:
                              continue
                          if (not allow_trivial) and (u == v == w):
                              continue
                          if (best_cw is None) or (cw < best_cw):
                              best_cw = cw
                              best = (triple, w)

          if best is None:
              return None, GX, GY, None

          triple, w_best = best
          GX[r+1] = w_best
          GY[r+1] = (self.rol(GY[r], self.beta) ^ w_best) & M
          triples.append(triple)
          total_cw += best_cw

      return triples, GX, GY, total_cw

    def gen_pairs(self, Npairs, rounds=None, seed=1234):
        """Genera Npairs de (P,C) cifrando con las round_keys cargadas."""
        if self.round_keys is None:
            raise ValueError("round_keys no inicializadas. Llama key_schedule(key)." )
        rng = np.random.default_rng(seed)
        n = self.word_size
        m = (1 << n) - 1
        R = self.n_rounds if rounds is None else int(rounds)
        out = []
        for _ in range(int(Npairs)):
            P = (int(rng.integers(0, 1<<n)) & m, int(rng.integers(0, 1<<n)) & m)
            C = self.encrypt(P, rounds=R, key=None, trace=False)
            out.append((P, C))
        return out

    def _mask_bit_positions(self, w):
        n = self.word_size
        return [i for i in range(n) if (w >> i) & 1]

    def matsui1_last_round_score_keyed(self, pairs, ax, ay, gx, gy_prime=0, w_last=None):
        """Matsui-1 'keyed' para la ÚLTIMA ronda"""
        n = self.word_size

        if w_last is None:
            w_last = gx
        if w_last == 0:
            raise ValueError("w_last es 0: no hay bits de clave para adivinar.")

        bitpos = [i for i in range(n) if (w_last >> i) & 1]
        scores = {}

        for g in range(1 << len(bitpos)):
            key_guess = 0
            for j, pos in enumerate(bitpos):
                if (g >> j) & 1:
                    key_guess |= (1 << pos)

            bias_counter = 0
            for (_, C) in pairs:
                x1, y1 = C  # ciphertext (x',y')
                x, y = self.partial_decrypt_last_round(C, [key_guess], stop_at="after_rol_alpha")

                lhs = ( self.parity(x  & ax)
                      ^ self.parity(y  & ay)
                      ^ self.parity(x1 & gx)
                      ^ self.parity(y1 & gy_prime) )
                bias_counter += (lhs == 0) - (lhs == 1)

            scores[key_guess] = abs(bias_counter)

        ranked = sorted(scores.items(), key=lambda kv: kv[1], reverse=True)
        return ranked

    def estimate_bias_of_triple(self, u, v, w, samples=200_000, seed=2025):
        """Muestreo simple para ver p y |eps| de una triple (u,v,w) n-bit."""
        rng = np.random.default_rng(seed)
        n = self.word_size; m = (1<<n)-1
        cnt = 0
        for _ in range(samples):
            X = int(rng.integers(0, 1<<n)) & m
            Y = int(rng.integers(0, 1<<n)) & m
            Z = (X + Y) & m
            lhs = (self.parity(X & u) ^ self.parity(Y & v) ^ self.parity(Z & w))
            cnt += (lhs == 0)
        p = cnt / samples
        eps = abs(p - 0.5)
        return p, eps

    @staticmethod
    def _bits_set_(x: int, n: int):
        """Devuelve posiciones 0..n-1 con bit=1 en x."""
        return [i for i in range(n) if (x >> i) & 1]

    @staticmethod
    def _gen_w_candidates_(n: int, u: int, v: int, max_two_bit_pairs: int | None = None):
        """Genera candidatos w priorizando cercanía a u y v."""
        seen = set()
        order = []

        bu = Speck._bits_set_(u, n)
        bv = Speck._bits_set_(v, n)
        allpos = list(range(n))

        # 1-bit: u -> v -> resto
        for pos in bu + [p for p in bv if p not in bu] + [p for p in allpos if (p not in bu) and (p not in bv)]:
            w = 1 << pos
            if w not in seen:
                seen.add(w); order.append(w)

        # 2-bits cercanos
        pairs = []
        for i in range(len(bu)):
            for j in range(i+1, len(bu)):
                pairs.append((bu[i], bu[j]))
        for i in range(len(bv)):
            for j in range(i+1, len(bv)):
                pairs.append((bv[i], bv[j]))
        for i in bu:
            for j in bv:
                if i != j:
                    a, b = (i, j) if i < j else (j, i)
                    pairs.append((a, b))
        for i in range(n):
            for j in range(i+1, n):
                pairs.append((i, j))

        seen_pair = set()
        two_bit_ws = []
        for i, j in pairs:
            key = (i, j)
            if key in seen_pair:
                continue
            seen_pair.add(key)
            two_bit_ws.append((1 << i) | (1 << j))
            if (max_two_bit_pairs is not None) and (len(two_bit_ws) >= max_two_bit_pairs):
                break

        for w in two_bit_ws:
            if w not in seen:
                seen.add(w); order.append(w)

        return order

# %% [markdown]
# ## Build graph from the loaded cLAT

# %%
clatb = payload["cLATb"]

# ---------- helpers ----------
def _to_int_mask(x: Any) -> int:
    if isinstance(x, (int, np.integer)):
        return int(x)
    s = str(x).strip()
    if s.startswith("(") and s.endswith(")"):
        s = s[1:-1]
    try:
        return int(s, 0)          # soporta "0x..."
    except Exception:
        return int(float(s))

def _bias_from_cw(cw: Any) -> float:
    # cw es peso de correlación → |bias| = 2^{-cw}
    return float(2.0 ** (-float(cw)))

def _best_bias_from_dicts(dicts: Iterable[dict]) -> float:
    """
    Recibe una colección de dicts tipo {'conn': a, 'cw': 8} o {'bias': 0.03125}
    y devuelve el "mejor" bias:
      - si hay 'cw': el menor cw (sesgo más fuerte)
      - si hay 'bias'/'corr': el de mayor |bias|
    """
    best = None
    have_cw = any('cw' in d for d in dicts)

    if have_cw:
        # elegir el menor cw
        min_cw = None
        for d in dicts:
            if 'cw' in d:
                cw = float(d['cw'])
                if (min_cw is None) or (cw < min_cw):
                    min_cw = cw
        if min_cw is not None:
            return _bias_from_cw(min_cw)

    # si no hubo 'cw', intenta por bias/corr y usa mayor |bias|
    for d in dicts:
        if 'bias' in d:
            val = float(d['bias'])
        elif 'corr' in d:
            val = float(d['corr'])
        elif 'epsilon' in d or 'eps' in d or 'e' in d or 'c' in d:
            for k in ('epsilon', 'eps', 'e', 'c'):
                if k in d:
                    val = float(d[k]); break
        else:
            continue
        if (best is None) or (abs(val) > abs(best)):
            best = val

    if best is None:
        raise ValueError("No se pudo determinar bias en dicts de acciones.")
    return float(best)

def _extract_bias(bd: Any) -> float:
    """
    Acepta:
      - escalar (int/float/np.*)
      - dict plano con 'bias'/'corr' o con 'cw'
      - dict de acciones: {0: {...}, 1: {...}}  -> elige mejor acción
    """
    # escalar
    if isinstance(bd, (int, float, np.floating, np.integer)):
        return float(bd)

    if not isinstance(bd, dict):
        raise ValueError(f"Unexpected 'bd' type: {type(bd)} → {bd!r}")

    # --- caso: dict de acciones (values también son dicts con cw/bias) ---
    if bd and all(isinstance(v, dict) for v in bd.values()) and \
       any(('cw' in v) or ('bias' in v) or ('corr' in v) or ('epsilon' in v) or ('eps' in v) or ('e' in v) or ('c' in v)
           for v in bd.values()):
        return _best_bias_from_dicts(bd.values())

    # --- caso: dict plano con cw/bias ---
    for k in ("bias", "corr", "epsilon", "eps", "e", "c"):
        if k in bd:
            return float(bd[k])
    for k in ("cw", "weight", "cweight", "corr_weight"):
        if k in bd:
            return _bias_from_cw(bd[k])

    # último recurso: primer valor numérico
    for v in bd.values():
        if isinstance(v, (int, float, np.floating, np.integer)):
            return float(v)

    raise ValueError(f"Could not extract bias from bd={bd}")

# ---------- construcción de edges ----------
def build_edges_from_payload(payload: dict):
    # Fuente principal
    src = payload["cLATb"] if "cLATb" in payload else payload["cLATw"]

    edges = defaultdict(list)
    count = 0

    for u, vd in src.items():
        uu = _to_int_mask(u)
        for v, wd in vd.items():
            vv = _to_int_mask(v)

            # wd es mapa w -> bd (bd puede ser: escalar, dict plano, o dict de acciones)
            if isinstance(wd, dict):
                for w, bd in wd.items():
                    ww = _to_int_mask(w)
                    bias = _extract_bias(bd)   # <-- ahora soporta dict de acciones
                    edges[(uu, vv)].append((ww, float(bias)))
                    count += 1
            else:
                # Raro pero lo manejamos: v → bias directo (sin w), asumimos w=0
                ww = 0
                bias = _extract_bias(wd)
                edges[(uu, vv)].append((ww, float(bias)))
                count += 1

    return edges, count

# ---------- uso ----------
edges, count = build_edges_from_payload(payload)
print(f"Built edges for {len(edges)} (u,v) states with {count} transitions total.")
peek_key = next(iter(edges))
print("Sample state:", peek_key, "->", edges[peek_key][:3])
# Out:
# Built edges for 65536 (u,v) states with 780994 transitions total.
# Sample state: (0, 0) -> [(0, 0.0), (1, 0.0), (2, 0.0)]

# %%
def _to_int(x):
    if isinstance(x, (int, np.integer)): return int(x)
    return int(str(x), 0)

def _bias_from_cw(cw, cw_on="epsilon"):
    cw = float(cw)
    return 2.0 ** (-(cw + 1.0)) if cw_on == "epsilon" else 2.0 ** (-cw)

def build_edges_with_b(payload, cw_on="epsilon"):
    # Usa cLATb porque es la que contiene {conn, cw} indexado por 'b'
    src = payload["cLATb"]
    edges_b = defaultdict(list)   # (u,v,b) -> [(w, bias, b_next)]
    count = 0
    for u, vd in src.items():
        uu = _to_int(u)
        for v, wd in vd.items():
            vv = _to_int(v)
            for w, bd in wd.items():
                ww = _to_int(w)
                # bd es dict indexado por b: {0:{conn,cw}, 1:{conn,cw}} (a veces falta uno)
                for b_key, rec in bd.items():
                    b = int(b_key)
                    if isinstance(rec, dict):
                        cw = rec.get("cw", payload["m"])
                        conn = int(rec.get("conn", 0))  # b_next
                    else: # rec is an int, assume it's the cw value
                        cw = int(rec)
                        conn = 0 # Default connection for integer rec
                    bias = _bias_from_cw(cw, cw_on=cw_on)
                    edges_b[(uu, vv, b)].append((ww, float(bias), conn))
                    count += 1
    return edges_b, count

edges_b, count = build_edges_with_b(payload, cw_on="epsilon")
print(f"Built edges_b for {len(edges_b)} (u,v,b) states with {count} transitions.")
peek = next(iter(edges_b))
print("Sample:", peek, "->", edges_b[peek][:3])
# Out:
# Built edges_b for 87382 (u,v,b) states with 781250 transitions.
# Sample: (0, 0, 0) -> [(0, 0.5, 0)]

# %% [markdown]
# ## Environment

# %%
speck = Speck(n_rounds=22, word_size=16, alpha=7, beta=2, m=4)
WORD_BITS = speck.word_size
ALPHA     = speck.alpha
BETA      = speck.beta
MASK      = speck.mask_val

# ========= Utils =========
import math, random
from collections import defaultdict

def _get(d, k):  # soporta claves int/str en el pickle
    return d[k] if k in d else d[str(k)]

def _bias_from_cw(cw: float) -> float:
    # si cw es sobre correlación: |ε|=2^{-cw} ⇒ |bias|=|ε|/2 = 2^{-(cw+1)}
    return 2.0 ** (-(float(cw) + 1.0))


# ========= Entorno jerárquico 8→16 =========
# Estado: (uH, uL, vH, vL, b, phase)  con phase∈{0,1} (elige wH y luego wL)
# Acción: w8 (0..255)
# Recompensa por ronda: |bias| con bias = 2^{-(cwH+cwL+1)}
# === reemplaza tu clase por esta versión (cambia solo reset + helper) ===
class EnvHier8to16:
    def __init__(self, payload: dict, speck16, rounds: int = 6,
                 reward_mode: str = "abs", carry: str = "zero"):
        self.P = payload; self.S = speck16
        self.R = int(rounds); self.reward_mode = reward_mode
        assert carry in ("zero","propagate")
        self.carry = carry
        self._rng = random.Random()
        self.reset()

    def _get(self, d, k):
        return d[k] if k in d else d[str(k)]

    def _row_for(self, u: int, v: int):
        try:
            return self._get(self._get(self.P["cLATb"], u), v)
        except Exception:
            return {}

    def _extract_cw_conn(self, rec):
        """Helper to extract cw and conn from a record, handling int or dict."""
        if isinstance(rec, dict):
            cw = rec.get("cw", self.P["m"]) # Use payload["m"] as default cw
            conn = int(rec.get("conn", 0))
        else: # rec is an int, assume it's the cw value
            cw = int(rec)
            conn = 0 # Default connection for integer rec
        return cw, conn

    def _sample_valid_state(self, trials=5000):
        """Devuelve (uH,uL,vH,vL,b,phase) con al menos 1 acción válida en phase=0."""
        cN = self.P["cLATN"]; cU = self.P["cLATu"]; cW = self.P["cLATw"]; cB = self.P["cLATb"]
        def get(d,k): return d[k] if k in d else d[str(k)]
        for _ in range(trials):
            v16 = self._rng.randrange(1<<16)
            vH, vL = (v16>>8)&0xFF, v16&0xFF
            b = 0  # arrancamos con b_in=0

            # Elegir (uH, wH) válidos para (vH,b=0)
            nh = get(get(cN, vH), b)
            if not nh:
                continue
            # coge un cw al azar y uno de sus índices
            cwHk = self._rng.choice(list(nh.keys()))
            uH_list = get(get(get(cU, vH), b), cwHk)
            wH_list = get(get(get(cW, vH), b), cwHk)
            idxH = self._rng.randrange(len(uH_list))
            uH = int(uH_list[idxH]); wH = int(wH_list[idxH])

            # bH (carry entre mitades)
            rec_value_for_bH = get(get(get(get(cB, uH), vH), wH), b)
            _, bH = self._extract_cw_conn(rec_value_for_bH)

            # Chequear que exista al menos un wL válido para (uL, vL, bH)
            nl = get(get(cN, vL), bH)
            if not nl:
                continue
            cwLk = self._rng.choice(list(nl.keys()))
            uL_list = get(get(get(cU, vL), bH), cwLk)
            if not uL_list:
                continue
            uL = int(self._rng.choice(list(uL_list)))

            # ¡Listo! hay acción en phase=0
            return (uH, uL, vH, vL, 0, 0)
        # Si no encontramos en trials, cae a (0,0,0,0) pero con phase=0 sin acciones
        return (0,0,0,0,0,0)

    # --- API ---
    def reset(self, init_state=None):
        self.t = 0
        if init_state is None:
            self.uH, self.uL, self.vH, self.vL, self.b, self.phase = self._sample_valid_state()
        else:
            self.uH, self.uL, self.vH, self.vL, self.b, self.phase = init_state
        self.partial = None
        return (self.uH, self.uL, self.vH, self.vL, self.b, self.phase)

    def actions(self, s=None):
        uH,uL,vH,vL,b,phase = (s if s is not None else
                               (self.uH,self.uL,self.vH,self.vL,self.b,self.phase))
        if phase == 0:
            row = self._row_for(uH, vH)
            valid_ws = []
            for w, bd_for_w in row.items():
                if bd_for_w and (b in bd_for_w or str(b) in bd_for_w):
                    valid_ws.append(w)
            return valid_ws
        else:
            assert self.partial is not None, "Fase baja sin parcial"
            bH = self.partial[2]
            row = self._row_for(uL, vL)
            valid_ws = []
            for w, bd_for_w in row.items():
                if bd_for_w and (bH in bd_for_w or str(bH) in bd_for_w):
                    valid_ws.append(w)
            return valid_ws

    def step(self, w: int):
        if self.phase == 0:
            bd = self._row_for(self.uH, self.vH).get(w, {})
            rec = bd.get(self.b)
            if rec is None:
                return (self.uH,self.uL,self.vH,self.vL,self.b,self.phase), -1e2, True, {"error":"invalid_action_hi"}
            cwH, bH = self._extract_cw_conn(rec)
            self.partial = (w, cwH, bH)
            self.phase = 1
            return (self.uH,self.uL,self.vH,self.vL,self.b,self.phase), 0.0, False, {"phase":"lo"}

        # phase == 1
        wH, cwH, bH = self.partial
        bd = self._row_for(self.uL, self.vL).get(w, {})
        rec = bd.get(bH)
        if rec is None:
            return (self.uH,self.uL,self.vH,self.vL,self.b,self.phase), -1e2, True, {"error":"invalid_action_lo"}

        cwL, _ = self._extract_cw_conn(rec)
        cw = cwH + cwL
        bias = 2.0 ** (-(float(cw) + 1.0))
        reward = abs(bias) if self.reward_mode == "abs" else math.log2(max(abs(bias), 1e-300))

        w16 = ((wH & 0xFF) << 8) | (w & 0xFF)
        v16 = ((self.vH & 0xFF) << 8) | (self.vL & 0xFF)
        up = self.S.ror(w16, self.S.alpha) & self.S.mask_val
        vp = (self.S.rol(v16, self.S.beta) ^ w16) & self.S.mask_val

        self.uH, self.uL = (up >> 8) & 0xFF, up & 0xFF
        self.vH, self.vL = (vp >> 8) & 0xFF, vp & 0xFF
        self.b = (self.partial[2] if self.carry == "propagate" else 0)
        self.phase = 0
        self.t += 1

        done = (self.t >= self.R) or (len(self.actions()) == 0)
        return (self.uH,self.uL,self.vH,self.vL,self.b,self.phase), reward, done, {
            "cw_round": cw, "bias_round": bias, "w16": w16
        }

# %%
R_ROUNDS   = 6
env   = EnvHier8to16(payload, speck, rounds=R_ROUNDS, reward_mode="abs", carry="zero")
s = env.reset()
print("Init state:", s)
print("Phase:", s[-1], " | #actions:", len(env.actions(s)))
a = random.choice(env.actions(s))
s2, r, done, info = env.step(a)
print("After 1st step → phase:", s2[-1], " reward:", r, " done:", done)
if s2[-1] == 1:
    a2 = random.choice(env.actions(s2))
    s3, r2, done2, info2 = env.step(a2)
    print("Closed round → reward:", r2, " done:", done2, " info:", info2)
# Out:
# Init state: (109, 26, 90, 29, 0, 0)
# Phase: 0  | #actions: 4
# After 1st step → phase: 1  reward: 0.0  done: False
# Closed round → reward: 0.5  done: True  info: {'cw_round': 0, 'bias_round': 0.5, 'w16': 30230}

# %% [markdown]
# ## Agent

# %%
import math, random, pickle, numpy as np
from collections import defaultdict

# ========= Agente Q-learning (tabular) =========
class QAgent:
    def __init__(self, epsilon=0.25, alpha=0.30, gamma=1.0):
        self.Q = defaultdict(lambda: defaultdict(float))
        self.epsilon=float(epsilon); self.alpha=float(alpha); self.gamma=float(gamma)

    def policy(self, s, actions):
        if not actions: return None
        if random.random() < self.epsilon:
            return random.choice(actions)     # acción = w8
        qs = self.Q[s]
        return max(actions, key=lambda a: (qs[a], random.random()))

    def update(self, s, a, r, s_next, next_actions):
        qsa = self.Q[s][a]
        max_next = max((self.Q[s_next][ap] for ap in next_actions), default=0.0)
        self.Q[s][a] = qsa + self.alpha * (r + self.gamma*max_next - qsa)

# ========= Hiperparámetros =========
EPISODES   = 5000
R_ROUNDS   = 6
MAX_STEPS  = 2 * R_ROUNDS   # <- clave para el entorno jerárquico
EPSILON0   = 0.25
ALPHA_Q    = 0.30
GAMMA      = 1.0
SEED       = 1337
EPSILON_END   = 0.01

random.seed(SEED); np.random.seed(SEED)

env   = EnvHier8to16(payload, speck, rounds=R_ROUNDS, reward_mode="abs", carry="zero")
agent = QAgent(epsilon=EPSILON0, alpha=ALPHA_Q, gamma=GAMMA)
EPS_DECAY = (EPSILON_END / EPSILON0) ** (1.0 / EPISODES)

returns, best_ret, best_path = [], -1e9, None

for ep in range(1, EPISODES+1):
    s = env.reset()
    total = 0.0
    path  = [s]

    for _ in range(MAX_STEPS):
        acts = env.actions(s)
        if not acts: break
        a = agent.policy(s, acts)
        s_next, r, done, info = env.step(a)
        total += r
        agent.update(s, a, r, s_next, env.actions(s_next))
        s = s_next
        path.append(s)
        if done: break

    returns.append(total)
    if total > best_ret:
        best_ret, best_path = total, path

    # Decaimiento más lento con piso real
    agent.epsilon *= EPS_DECAY
    # ================================================

    if ep % 500 == 0:
        avg500 = float(np.mean(returns[-500:])) if len(returns) >= 500 else float(np.mean(returns))
        print(f"Episode {ep}/{EPISODES}  avg(last500)={avg500:.4f}  best={best_ret:.4f}  eps={agent.epsilon:.3f}")


# Guardar Q-Table
with open("qtable_hier_8to16.pkl","wb") as f:
    pickle.dump({str(k): dict(v) for k, v in agent.Q.items()}, f, protocol=pickle.HIGHEST_PROTOCOL)

print("Saved Q-table to qtable_hier_8to16.pkl")
print("Best return:", best_ret, " best path length:", len(best_path))
# Out:
# Episode 500/5000  avg(last500)=0.3367  best=1.2500  eps=0.181
# Episode 1000/5000  avg(last500)=0.3165  best=1.2500  eps=0.131
# Episode 1500/5000  avg(last500)=0.3152  best=1.2500  eps=0.095
# Episode 2000/5000  avg(last500)=0.3217  best=1.2500  eps=0.069
# Episode 2500/5000  avg(last500)=0.3120  best=1.2500  eps=0.050
# Episode 3000/5000  avg(last500)=0.3240  best=1.2500  eps=0.036
# Episode 3500/5000  avg(last500)=0.3192  best=1.6250  eps=0.026
# Episode 4000/5000  avg(last500)=0.3232  best=1.6250  eps=0.019
# Episode 4500/5000  avg(last500)=0.3242  best=1.6250  eps=0.014
# Episode 5000/5000  avg(last500)=0.3247  best=1.6250  eps=0.010
# Saved Q-table to qtable_hier_8to16.pkl
# Best return: 1.625  best path length: 9

# %% [markdown]
# ## Learning curve

# %%
if 'returns' in globals() and returns:
    plt.figure()
    w = min(200, len(returns))
    ma = np.convolve(returns, np.ones(w)/w, mode='valid')
    plt.plot(ma)
    plt.title("Learning Curve (moving average of returns)")
    plt.xlabel("Episode"); plt.ylabel("Return (sum log₂ |bias|)")
    plt.show()
else:
    print("Nada que graficar aún.")

# %% [markdown]
# # Evaluate hulls

# %%
from dataclasses import dataclass
from typing import Callable, Any, List, Optional, Tuple

@dataclass
class StepLog:
    t: int
    state: Any               # (uH,uL,vH,vL,b,phase)
    action: Optional[int]    # w8
    reward: float
    next_state: Any
    done: bool
    info: dict               # cw_round, bias_round, w16, etc.
    q_values: Optional[List[Tuple[int, float]]] = None  # [(a, Q(s,a)), ...]

@dataclass
class PathLog:
    steps: List[StepLog]
    return_: float

# ------------------------------------------------------------
# Helpers de política/Q
# ------------------------------------------------------------
def actions_of(env: EnvHier8to16, s) -> List[int]:
    return list(env.actions(s))

def q_values_of(agent: QAgent, s, actions: List[int]) -> List[Tuple[int,float]]:
    qs = agent.Q[s]  # defaultdict(float)
    return [(a, qs[a]) for a in actions]

def argmax_q(qsa: List[Tuple[int,float]]) -> Optional[int]:
    return max(qsa, key=lambda x: (x[1], random.random()))[0] if qsa else None

# ------------------------------------------------------------
# Rollout GREEDY (ε=0)
# ------------------------------------------------------------
def rollout_greedy(env: EnvHier8to16, agent: QAgent, init_state, max_steps: int = 64) -> PathLog:
    s = env.reset(init_state=init_state)
    steps: List[StepLog] = []
    G = 0.0
    for t in range(max_steps):
        acts = actions_of(env, s)
        if not acts:
            steps.append(StepLog(t, s, None, 0.0, s, True, {"note":"no_actions"}, None))
            break
        qsa = q_values_of(agent, s, acts)
        a = argmax_q(qsa)  # sin exploración
        s_next, r, done, info = env.step(a)
        steps.append(StepLog(t, s, a, r, s_next, bool(done), info, qsa))
        G += r
        s = s_next
        if done:
            break
    return PathLog(steps=steps, return_=G)

# ------------------------------------------------------------
# N rollouts con ε fijo (no toca agent.epsilon global)
# ------------------------------------------------------------
def rollout_eps(env: EnvHier8to16, agent: QAgent, init_state, eps: float, n: int = 5, max_steps: int = 64) -> List[PathLog]:
    paths = []
    for _ in range(n):
        s = env.reset(init_state=init_state)
        steps: List[StepLog] = []
        G = 0.0
        for t in range(max_steps):
            acts = actions_of(env, s)
            if not acts:
                steps.append(StepLog(t, s, None, 0.0, s, True, {"note":"no_actions"}, None))
                break
            if random.random() < eps:
                a = random.choice(acts)
                qsa = q_values_of(agent, s, acts)
            else:
                qsa = q_values_of(agent, s, acts)
                a = argmax_q(qsa)
            s_next, r, done, info = env.step(a)
            steps.append(StepLog(t, s, a, r, s_next, bool(done), info, qsa))
            G += r
            s = s_next
            if done:
                break
        paths.append(PathLog(steps=steps, return_=G))
    return paths

# ------------------------------------------------------------
# Beam search (Top-K) guiado por Q
# ------------------------------------------------------------
def beam_search_paths(env_factory: Callable[[], EnvHier8to16],
                      agent: QAgent,
                      init_state,
                      K: int = 5,
                      depth: int = 8) -> List[PathLog]:
    """
    Mantiene un haz de K trayectorias; expansión ordenada por Q(s,a).
    Guarda y restaura 'partial' cuando el estado está en phase=1.
    Score = return real + (si no done) max_a' Q(s',a') como heurística.
    """

    # BeamItem: (score, PathLog, state, partial)
    # partial es None o una tupla (wH, cwH, bH) válida para phase=1
    def reset_with_state_and_partial(env: EnvHier8to16, s, partial):
        env.reset(init_state=s)
        # Si el estado está en phase=1 y tenemos partial, rehidrátalo
        if s[-1] == 1 and partial is not None:
            env.partial = partial
        return env

    # Inicialización
    env0 = env_factory()
    s0 = env0.reset(init_state=init_state)
    # Acciones iniciales (phase=0 esperado; si no, no pasa nada, sólo se usará lo que haya)
    acts0 = actions_of(env0, s0)
    q0 = q_values_of(agent, s0, acts0)
    h0 = max([q for _, q in q0], default=0.0)
    beam: List[Tuple[float, PathLog, Any, Optional[Tuple[int,int,int]]]] = [
        (h0, PathLog(steps=[], return_=0.0), s0, None)  # al inicio no hay partial
    ]

    for d in range(depth):
        new_beam = []
        for score, path, s, partial in beam:
            # Crea un env y rehidrata partial si corresponde
            env = reset_with_state_and_partial(env_factory(), s, partial)
            acts = actions_of(env, s)
            if not acts:
                # Sin acciones: conservar la hoja
                new_beam.append((path.return_, path, s, partial))
                continue

            qsa = q_values_of(agent, s, acts)
            # Expandir por acciones con mejor Q primero
            for a, q in sorted(qsa, key=lambda x: x[1], reverse=True):
                # Clonar por construcción de un env nuevo desde (s, partial)
                env2 = reset_with_state_and_partial(env_factory(), s, partial)
                s_next, r, done, info = env2.step(a)  # esto actualiza env2.partial si pasa a phase=1
                step = StepLog(d, s, a, r, s_next, bool(done), info, qsa)
                new_path = PathLog(path.steps + [step], path.return_ + r)

                # Heurística: max Q en s_next
                h = 0.0
                if not done:
                    acts_next = actions_of(env2, s_next)  # válido: env2 ya trae partial si s_next.phase==1
                    qnext = q_values_of(agent, s_next, acts_next)
                    h = max([qq for _, qq in qnext], default=0.0)

                # Transportar partial del env2 junto con el siguiente estado
                next_partial = getattr(env2, "partial", None)
                new_beam.append((new_path.return_ + h, new_path, s_next, next_partial))

        # Top-K por score
        new_beam.sort(key=lambda x: x[0], reverse=True)
        beam = new_beam[:K]

        # Cortar si todos ya terminaron
        if all(p.steps and p.steps[-1].done for _, p, _, _ in beam):
            break

    # Devolver sólo los caminos, ordenados por retorno real
    out = [p for _, p, _, _ in beam]
    out.sort(key=lambda p: p.return_, reverse=True)
    return out

# %% [markdown]
# ## Helpers

# %%
def fmt_state(s):
    uH,uL,vH,vL,b,phase = s
    return f"(uH={uH:02X},uL={uL:02X},vH={vH:02X},vL={vL:02X},b={b},ph={phase})"

def fmt_action(a):
    return "∅" if a is None else f"w8={a:02X}"

def pretty_path(path: PathLog) -> str:
    lines = [f"Return = {path.return_:.6e}, steps = {len(path.steps)}"]
    G = 0.0
    for st in path.steps:
        G += st.reward
        info = st.info or {}
        cw   = info.get("cw_round", None)
        bias = info.get("bias_round", None)
        w16  = info.get("w16", None)
        extra = []
        if cw is not None:   extra.append(f"cw={cw}")
        if bias is not None: extra.append(f"bias={bias:.3e}")
        if w16 is not None:  extra.append(f"w16={w16:04X}")
        best_a = None; best_q = None
        if st.q_values:
            best_a, best_q = max(st.q_values, key=lambda x: x[1])
        best_str = f" | best={best_a:02X} Q={best_q:.3e}" if best_a is not None else ""
        lines.append(
            f"t={st.t:02d}  s={fmt_state(st.state)}  a={fmt_action(st.action)}  "
            f"r={st.reward:.3e}  -> s'={fmt_state(st.next_state)}  done={st.done}  "
            + (" ".join(extra) if extra else "") + best_str
        )
    lines.append(f"==> G = {G:.6e}")
    return "\n".join(lines)

def first_valid_hi_action(env: EnvHier8to16, s):
    """Devuelve el primer wH válido para phase=0 en el estado s (o None)."""
    uH,uL,vH,vL,b,phase = s
    assert phase == 0
    row = env._row_for(uH, vH) or {}
    for w, bd in row.items():
        if (bd is not None) and ((b in bd) or (str(b) in bd)):
            return int(w)
    return None

# %% [markdown]
# ## Evaluate function

# %%
def evaluate(env: EnvHier8to16,
             agent: QAgent,
             init_state=None,
             n_eps_paths: int = 3,
             eps: float = 0.10,
             do_beam: bool = True,
             K: int = 5,
             depth: int = 8,
             ensure_valid: bool = True):
    """
    - Si init_state es None o no tiene acciones y ensure_valid=True, usa _sample_valid_state().
    - Imprime GREEDY + N rollouts con ε + Top-K (opcional).
    """
    if init_state is None:
        s0 = env._sample_valid_state() if ensure_valid else env.reset()
    else:
        s0 = init_state

    if not env.actions(s0) and ensure_valid:
        s0 = env._sample_valid_state()

    print("Estado inicial:", fmt_state(s0))
    print("Acciones disponibles en s0:", env.actions(s0))

    greedy = rollout_greedy(env, agent, init_state=s0, max_steps=2*env.R)
    print("\n=== GREEDY ===")
    print(pretty_path(greedy))

    eps_paths = rollout_eps(env, agent, init_state=s0, eps=eps, n=n_eps_paths, max_steps=2*env.R)
    for i, p in enumerate(eps_paths, 1):
        print(f"\n=== EPS PATH #{i} (eps={eps}) ===")
        print(pretty_path(p))

    if do_beam:
        def make_env():
            # Debe devolver un env fresco del mismo tipo:
            return EnvHier8to16(env.P, env.S, rounds=env.R, reward_mode=env.reward_mode, carry=env.carry)
        topk = beam_search_paths(make_env, agent, init_state=s0, K=K, depth=depth)
        for i, p in enumerate(topk, 1):
            print(f"\n=== TOP-{i} (return={p.return_:.6e}) ===")
            print(pretty_path(p))

# %% [markdown]
# ## Evaluate

# %%
# =========================================
#  A) Evaluar desde un estado específico
# =========================================
s0 = (0x12, 0x34, 0xAB, 0xCD, 0, 0)  # phase=0 -> elige wH primero

# Imprime: GREEDY, 3 rollouts con ε=0.10, y Top-K (K=5, depth=8)
evaluate(
    env,
    agent,
    init_state=s0,
    n_eps_paths=3,
    eps=0.10,
    do_beam=True,
    K=5,
    depth=8,
    ensure_valid=True  # si s0 no tiene acciones, toma uno válido similar automáticamente
)
# Out:
# Estado inicial: (uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)
# Acciones disponibles en s0: [169, 172, 173, 175, 177, 180, 181, 183, 201, 204, 205, 207, 209, 212, 213, 215]
#
# === GREEDY ===
# Return = 1.250000e-01, steps = 2
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=D1  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=21  r=1.250e-01  -> s'=(uH=43,uL=A2,vH=35,vL=C6,b=0,ph=0)  done=True  cw=2 bias=1.250e-01 w16=D121 | best=21 Q=0.000e+00
# ==> G = 1.250000e-01
#
# === EPS PATH #1 (eps=0.1) ===
# Return = 2.500000e-01, steps = 4
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=B5  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=2B  r=2.500e-01  -> s'=(uH=57,uL=6A,vH=51,vL=CC,b=0,ph=0)  done=False  cw=1 bias=2.500e-01 w16=B52B | best=21 Q=0.000e+00
# t=02  s=(uH=57,uL=6A,vH=51,vL=CC,b=0,ph=0)  a=w8=45  r=0.000e+00  -> s'=(uH=57,uL=6A,vH=51,vL=CC,b=0,ph=1)  done=False   | best=45 Q=0.000e+00
# t=03  s=(uH=57,uL=6A,vH=51,vL=CC,b=0,ph=1)  a=∅  r=0.000e+00  -> s'=(uH=57,uL=6A,vH=51,vL=CC,b=0,ph=1)  done=True
# ==> G = 2.500000e-01
#
# === EPS PATH #2 (eps=0.1) ===
# Return = 1.250000e-01, steps = 2
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=D4  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=21  r=1.250e-01  -> s'=(uH=43,uL=A8,vH=30,vL=C6,b=0,ph=0)  done=True  cw=2 bias=1.250e-01 w16=D421 | best=21 Q=0.000e+00
# ==> G = 1.250000e-01
#
# === EPS PATH #3 (eps=0.1) ===
# Return = 5.000000e-01, steps = 4
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=AD  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=29  r=5.000e-01  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  done=False  cw=0 bias=5.000e-01 w16=AD29 | best=21 Q=0.000e+00
# t=02  s=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  a=w8=5A  r=0.000e+00  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=1)  done=False   | best=59 Q=0.000e+00
# t=03  s=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=1)  a=∅  r=0.000e+00  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=1)  done=True
# ==> G = 5.000000e-01
#
# === TOP-1 (return=5.000000e-01) ===
# Return = 5.000000e-01, steps = 3
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=AD  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=29  r=5.000e-01  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  done=False  cw=0 bias=5.000e-01 w16=AD29 | best=21 Q=0.000e+00
# t=02  s=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  a=w8=59  r=0.000e+00  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=1)  done=False   | best=59 Q=0.000e+00
# ==> G = 5.000000e-01
#
# === TOP-2 (return=5.000000e-01) ===
# Return = 5.000000e-01, steps = 3
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=AD  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=29  r=5.000e-01  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  done=False  cw=0 bias=5.000e-01 w16=AD29 | best=21 Q=0.000e+00
# t=02  s=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  a=w8=5A  r=0.000e+00  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=1)  done=False   | best=59 Q=0.000e+00
# ==> G = 5.000000e-01
#
# === TOP-3 (return=5.000000e-01) ===
# Return = 5.000000e-01, steps = 3
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=AD  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=29  r=5.000e-01  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  done=False  cw=0 bias=5.000e-01 w16=AD29 | best=21 Q=0.000e+00
# t=02  s=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=0)  a=w8=5B  r=0.000e+00  -> s'=(uH=53,uL=5A,vH=49,vL=CE,b=0,ph=1)  done=False   | best=59 Q=0.000e+00
# ==> G = 5.000000e-01
#
# === TOP-4 (return=2.500000e-01) ===
# Return = 2.500000e-01, steps = 3
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=A9  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=29  r=2.500e-01  -> s'=(uH=53,uL=52,vH=4D,vL=CE,b=0,ph=0)  done=False  cw=1 bias=2.500e-01 w16=A929 | best=21 Q=0.000e+00
# t=02  s=(uH=53,uL=52,vH=4D,vL=CE,b=0,ph=0)  a=w8=5D  r=0.000e+00  -> s'=(uH=53,uL=52,vH=4D,vL=CE,b=0,ph=1)  done=False   | best=5D Q=0.000e+00
# ==> G = 2.500000e-01
#
# === TOP-5 (return=2.500000e-01) ===
# Return = 2.500000e-01, steps = 3
# t=00  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=0)  a=w8=A9  r=0.000e+00  -> s'=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  done=False   | best=A9 Q=0.000e+00
# t=01  s=(uH=AD,uL=31,vH=F9,vL=39,b=0,ph=1)  a=w8=29  r=2.500e-01  -> s'=(uH=53,uL=52,vH=4D,vL=CE,b=0,ph=0)  done=False  cw=1 bias=2.500e-01 w16=A929 | best=21 Q=0.000e+00
# t=02  s=(uH=53,uL=52,vH=4D,vL=CE,b=0,ph=0)  a=w8=5E  r=0.000e+00  -> s'=(uH=53,uL=52,vH=4D,vL=CE,b=0,ph=1)  done=False   | best=5D Q=0.000e+00
# ==> G = 2.500000e-01

# %%
# =========================================
#  A) Evaluar desde un estado específico
# =========================================
s0 = (0x00, 0x06, 0x00, 0x00, 0, 0)  # phase=0 -> elige wH primero

# Imprime: GREEDY, 3 rollouts con ε=0.10, y Top-K (K=5, depth=8)
evaluate(
    env,
    agent,
    init_state=s0,
    n_eps_paths=3,
    eps=0.10,
    do_beam=True,
    K=5,
    depth=8,
    ensure_valid=True  # si s0 no tiene acciones, toma uno válido similar automáticamente
)
# Out:
# Estado inicial: (uH=00,uL=06,vH=00,vL=00,b=0,ph=0)
# Acciones disponibles en s0: [0]
#
# === GREEDY ===
# Return = 0.000000e+00, steps = 2
# t=00  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=0)  a=w8=00  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=False   | best=00 Q=0.000e+00
# t=01  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  a=∅  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=True
# ==> G = 0.000000e+00
#
# === EPS PATH #1 (eps=0.1) ===
# Return = 0.000000e+00, steps = 2
# t=00  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=0)  a=w8=00  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=False   | best=00 Q=0.000e+00
# t=01  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  a=∅  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=True
# ==> G = 0.000000e+00
#
# === EPS PATH #2 (eps=0.1) ===
# Return = 0.000000e+00, steps = 2
# t=00  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=0)  a=w8=00  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=False   | best=00 Q=0.000e+00
# t=01  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  a=∅  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=True
# ==> G = 0.000000e+00
#
# === EPS PATH #3 (eps=0.1) ===
# Return = 0.000000e+00, steps = 2
# t=00  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=0)  a=w8=00  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=False   | best=00 Q=0.000e+00
# t=01  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  a=∅  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=True
# ==> G = 0.000000e+00
#
# === TOP-1 (return=0.000000e+00) ===
# Return = 0.000000e+00, steps = 1
# t=00  s=(uH=00,uL=06,vH=00,vL=00,b=0,ph=0)  a=w8=00  r=0.000e+00  -> s'=(uH=00,uL=06,vH=00,vL=00,b=0,ph=1)  done=False   | best=00 Q=0.000e+00
# ==> G = 0.000000e+00

# %% [markdown]
# # Multiple Masks Experiment

# %% [markdown]
# ## Helpers

# %%
from typing import List, Tuple, Union
import numpy as np

def load_masks(
    path: str,
    as_numpy: bool = True,
    dtype = np.uint16,
) -> Union[np.ndarray, List[int], List[Tuple[int, int]]]:
    """
    Carga máscaras desde un archivo de texto.

    Formatos soportados (por línea):
        0xAAAA
        0xAAAA    0xBBBB      (separado por espacio o tab)

    Parámetros
    ----------
    path : str
        Ruta al archivo .txt.
    as_numpy : bool, por defecto True
        - True  → devuelve np.ndarray
                 * 1 columna  → shape (n,)
                 * 2 columnas → shape (n, 2)
        - False → lista de enteros o lista de tuplas (x, y).
    dtype : tipo numpy, por defecto np.uint16
        Tipo de los enteros en el array.

    Returns
    -------
    np.ndarray o lista
    """
    xs: List[int] = []
    ys: List[int] = []

    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue  # saltar líneas vacías

            parts = line.split()
            if len(parts) == 1:
                # Solo una máscara por línea
                x = int(parts[0], 0)   # base automática (0x..., decimal, etc.)
                xs.append(x)
            elif len(parts) >= 2:
                # Tomamos solo las dos primeras columnas
                x = int(parts[0], 0)
                y = int(parts[1], 0)
                xs.append(x)
                ys.append(y)

    if as_numpy:
        if ys:  # hay segunda columna → pares
            arr_x = np.array(xs, dtype=dtype)
            arr_y = np.array(ys, dtype=dtype)
            return np.stack([arr_x, arr_y], axis=1)   # shape (n, 2)
        else:
            return np.array(xs, dtype=dtype)          # shape (n,)
    else:
        if ys:
            return list(zip(xs, ys))                  # [(x0, y0), ...]
        else:
            return xs                                 # [x0, x1, ...]

# %%
def masks_to_state(u16: int, v16: int, b: int = 0, phase: int = 0):
    """
    Convierte dos máscaras de 16 bits (u, v) en un estado (uH, uL, vH, vL, b, phase).
    """
    u16 &= 0xFFFF
    v16 &= 0xFFFF
    uH, uL = (u16 >> 8) & 0xFF, u16 & 0xFF
    vH, vL = (v16 >> 8) & 0xFF, v16 & 0xFF
    return (uH, uL, vH, vL, b, phase)

# %%
from math import inf

def max_return_for_masks(
    env: EnvHier8to16,
    agent: QAgent,
    u16: int,
    v16: int,
    n_eps_paths: int = 3,
    eps: float = 0.10,
    do_beam: bool = True,
    K: int = 5,
    depth: int = 8,
):
    """
    Devuelve el máximo retorno que alcanza el agente partiendo del estado
    definido por las máscaras (u16, v16).
    """
    # 1) estado inicial fijado por las máscaras
    s0 = masks_to_state(u16, v16, b=0, phase=0)

    # Si no hay acciones desde s0, devolvemos -inf (o None si prefieres)
    if not env.actions(s0):
        return float("-inf")

    # 2) rollout GREEDY
    greedy = rollout_greedy(env, agent, init_state=s0, max_steps=2 * env.R)
    best_return = greedy.return_

    # 3) rollouts con ε-greedy
    eps_paths = rollout_eps(
        env,
        agent,
        init_state=s0,
        eps=eps,
        n=n_eps_paths,
        max_steps=2 * env.R,
    )
    for p in eps_paths:
        if p.return_ > best_return:
            best_return = p.return_

    # 4) beam search: top-K caminos
    if do_beam:
        def make_env():
            return EnvHier8to16(
                env.P,
                env.S,
                rounds=env.R,
                reward_mode=env.reward_mode,
                carry=env.carry,
            )

        topk = beam_search_paths(
            make_env,
            agent,
            init_state=s0,
            K=K,
            depth=depth,
        )
        if topk:
            # beam_search_paths normalmente devuelve ya ordenado por retorno
            if topk[0].return_ > best_return:
                best_return = topk[0].return_

    return best_return

# %%
def retornos_pares(pares_list):
  retornos = []
  for par in pares_list:
      x = par[0] #Mascara izquierda
      y = par[1] #Mascara derecha
      retorno = max_return_for_masks(env, agent, x, y)
      retornos.append(retorno)
  return retornos

# %%
from math import inf

# 1) partir las máscaras de 16 bits en (uH, uL, vH, vL)
def split_uv(u16: int, v16: int, word_size: int = 16):
    """
    Convierte dos máscaras de 16 bits (u16, v16) en uH, uL, vH, vL (8 bits cada uno).
    Asumo Speck16 → word_size = 16 → 8 bits altos + 8 bits bajos.
    """
    mask = (1 << word_size) - 1      # 0xFFFF
    half = word_size // 2            # 8

    u16 &= mask
    v16 &= mask

    uH, uL = (u16 >> half) & ((1 << half) - 1), u16 & ((1 << half) - 1)
    vH, vL = (v16 >> half) & ((1 << half) - 1), v16 & ((1 << half) - 1)
    return uH, uL, vH, vL


# 2) buscar en env.S todos los estados cuyo (uH,uL,vH,vL) coincide
def estados_para_par(env, u16: int, v16: int, phase: int = 0):
    """
    Devuelve todos los estados s en env.S tales que:
        (uH,uL,vH,vL, b, phase_s) cumplen
        uH,uL,vH,vL = split_uv(u16, v16) y phase_s == phase.

    Asumo que un estado es una tupla:
        (uH, uL, vH, vL, b, phase)
    y que env.S es o bien:
        - un set/list de estados, o
        - un dict cuyo .keys() son los estados.
    """
    uH, uL, vH, vL = split_uv(u16, v16)

    S = env.S
    # si es dict, iteramos sobre las llaves; si no, sobre S directamente
    iterable = S.keys() if hasattr(S, "keys") else S

    candidatos = []
    for state in iterable:
        suH, suL, svH, svL, b, ph = state
        if suH == uH and suL == uL and svH == vH and svL == vL and ph == phase:
            candidatos.append(s)

    return candidatos

# %% [markdown]
# ## Experimento

# %%
pares_list = load_masks("pares_1234_abcd.txt", as_numpy=False)
print(pares_list[:5])   # [(x0, y0), (x1, y1), ...]
# Out:
# [(59609, 1053), (52778, 9745), (9397, 2744), (20654, 64609), (15017, 17805)]

# %%
calculated_retornos = retornos_pares(pares_list)

# %%
ret = np.array(calculated_retornos)
mask = np.isfinite(ret)
min_finite = ret[mask].min()

#A las parejas que no tienen estados validos, se les asigna un valor inferior al mínimo para gráficar
floor_val = min_finite - 5
ret_floor = np.where(mask, ret, floor_val)

# %% [markdown]
# ## Gráfica

# %%
len(pares_list)
# Out:
# 1000

# %%
len(calculated_retornos)
# Out:
# 1000

# %%
plt.figure(figsize=(8,6))
plt.scatter(range(len(pares_list)), ret_floor, s=5)   # s: tamaño del punto
plt.xlabel('Mask Index')
plt.ylabel('Return')
plt.title('Returns per mask')
plt.grid(True)
plt.show()

# %%
sorted_ret = np.sort(ret_floor)

plt.figure(figsize=(8,6))
plt.plot(sorted_ret, marker='.', linestyle='none')
plt.xlabel('Mask (ordenadas por retorno)')
plt.ylabel('Return')
plt.title('Distribución de retornos')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(4,6))
plt.boxplot(ret_floor, vert=True)
plt.ylabel('Return')
plt.title('Resumen de retornos')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pie chart para la distribución del piling up lemma

# %%
number_zeros =  (ret_floor == 0).sum()
print(number_zeros)
# Out:
# 221

# %%
value = -39
number_non_valid =  (ret_floor == value).sum()
print(number_non_valid)
# Out:
# 0

# %%
value = -34
number_thirty_four =  (ret_floor == value).sum()
print(number_thirty_four)
# Out:
# 0

# %%
value = -17
number_seventeen =  (ret_floor == value).sum()
print(number_seventeen)
# Out:
# 0

# %%
num_total = len(ret_floor)
print(num_total)
# Out:
# 1000

# %%
percentages = []
percentage_non_valid = (number_non_valid / num_total) * 100
percentages.append(percentage_non_valid)
percentage_zeros = (number_zeros / num_total) * 100
percentages.append(percentage_zeros)
percentage_thirty_four = (number_thirty_four / num_total) * 100
percentages.append(percentage_thirty_four)
percentage_seventeen = (number_seventeen / num_total) * 100
percentages.append(percentage_seventeen)

# %%
import matplotlib.pyplot as plt
import numpy as np

sizes  = percentages
labels = ['Non-valid', '0', '-34', '-17']

fig, ax = plt.subplots(figsize=(6, 5))

wedges, texts, autotexts = ax.pie(
    sizes,
    autopct='%1.1f%%',
    startangle=90,
    pctdistance=0.3
)

for i, w in enumerate(wedges):
    ang = 0.5 * (w.theta1 + w.theta2)
    x = np.cos(np.deg2rad(ang))
    y = np.sin(np.deg2rad(ang))

    xy = (0.9 * x, 0.9 * y)
    xytext = (1.4 * x, 1.4 * y)

    ax.annotate(
        labels[i],
        xy=xy,
        xytext=xytext,
        arrowprops=dict(arrowstyle='-', linewidth=1),
        ha='center',
        va='center'
    )

plt.subplots_adjust(top=0.8)

plt.title('Disitrbution of the piling up lemma with random masks', y=1.10)
ax.axis('equal')
plt.show()

# %% [markdown]
# ## Experimento con 0x0006 y 0x0000

# %%
pares_list = load_masks("pares_0006_0000.txt", as_numpy=False)
print(pares_list[:5])   # [(x0, y0), (x1, y1), ...]
# Out:
# [(1591, 18376), (12373, 61130), (34355, 25397), (23177, 5139), (13520, 16148)]

# %%
calculated_retornos = retornos_pares(pares_list)

# %%
ret = np.array(calculated_retornos)
mask = np.isfinite(ret)
min_finite = ret[mask].min()

#A las parejas que no tienen estados validos, se les asigna un valor inferior al mínimo para gráficar
floor_val = min_finite - 5
ret_floor = np.where(mask, ret, floor_val)

# %%
plt.figure(figsize=(8,6))
plt.scatter(range(len(pares_list)), ret_floor, s=5)   # s: tamaño del punto
plt.xlabel('Mask Index')
plt.ylabel('Return')
plt.title('Returns per mask')
plt.grid(True)
plt.show()

# %%
sorted_ret = np.sort(ret_floor)

plt.figure(figsize=(8,6))
plt.plot(sorted_ret, marker='.', linestyle='none')
plt.xlabel('Mask (ordenadas por retorno)')
plt.ylabel('Return')
plt.title('Distribución de retornos')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(4,6))
plt.boxplot(ret_floor, vert=True)
plt.ylabel('Return')
plt.title('Resumen de retornos')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pie chart para la distribución del piling up lemma

# %%
number_zeros =  (ret_floor == 0).sum()
print(number_zeros)
# Out:
# 224

# %%
value = -39
number_non_valid =  (ret_floor == value).sum()
print(number_non_valid)
# Out:
# 0

# %%
value = -34
number_thirty_four =  (ret_floor == value).sum()
print(number_thirty_four)
# Out:
# 0

# %%
value = -17
number_seventeen =  (ret_floor == value).sum()
print(number_seventeen)
# Out:
# 0

# %%
num_total = len(ret_floor)
print(num_total)
# Out:
# 1000

# %%
percentages = []
percentage_non_valid = (number_non_valid / num_total) * 100
percentages.append(percentage_non_valid)
percentage_zeros = (number_zeros / num_total) * 100
percentages.append(percentage_zeros)
percentage_thirty_four = (number_thirty_four / num_total) * 100
percentages.append(percentage_thirty_four)
percentage_seventeen = (number_seventeen / num_total) * 100
percentages.append(percentage_seventeen)

# %%
import matplotlib.pyplot as plt
import numpy as np

sizes  = percentages
labels = ['Non-valid', '0', '-34', '-17']

fig, ax = plt.subplots(figsize=(6, 5))

wedges, texts, autotexts = ax.pie(
    sizes,
    autopct='%1.1f%%',
    startangle=90,
    pctdistance=0.3
)

for i, w in enumerate(wedges):
    ang = 0.5 * (w.theta1 + w.theta2)
    x = np.cos(np.deg2rad(ang))
    y = np.sin(np.deg2rad(ang))

    xy = (0.9 * x, 0.9 * y)
    xytext = (1.4 * x, 1.4 * y)

    ax.annotate(
        labels[i],
        xy=xy,
        xytext=xytext,
        arrowprops=dict(arrowstyle='-', linewidth=1),
        ha='center',
        va='center'
    )

plt.subplots_adjust(top=0.8)

plt.title('Disitrbution of the piling up lemma with random masks', y=1.10)
ax.axis('equal')
plt.show()

# %% [markdown]
# ### Comparación con el algoritmo Matsui 3: Branch and Bound

# %% [markdown]
# #### Importar los caminos calculados con el algoritmo de matsui

# %%
df_matsui = pd.read_csv("matsui_from_1234_clat_full.csv")

# Asegurarnos de que alpha/beta sean enteros (no floats)
for col in ["alpha0", "beta0", "alphaR", "betaR",
            "seed_alpha0_dec", "seed_beta0_dec"]:
    # Fill NaN values with 0 before converting to int
    df_matsui[col] = df_matsui[col].fillna(300).astype(int)

df_matsui.head()
# Out:
#    seed_idx  seed_alpha0_dec  seed_beta0_dec seed_alpha0_hex seed_beta0_hex  \
# 0       768            59712              72          0xe940           0x48
# 1       496            38979             121          0x9843           0x79
# 2       544             7463             236          0x1d27           0xec
# 3       138            32798             165          0x801e           0xa5
# 4       963            42613             155          0xa675           0x9b
#
#    alpha0  beta0  alphaR  betaR alpha0_hex beta0_hex alphaR_hex betaR_hex  \
# 0   59712     72       0      0     0xe940      0x48        0x0       0x0
# 1   38979    121       1      1     0x9843      0x79        0x1       0x1
# 2    7463    236       0      0     0x1d27      0xec        0x0       0x0
# 3   32798    165       1      1     0x801e      0xa5        0x1       0x1
# 4   42613    155       1      1     0xa675      0x9b        0x1       0x1
#
#    cw_total
# 0       5.0
# 1       5.0
# 2       6.0
# 3       6.0
# 4       7.0

# %% [markdown]
# #### Helpers para el producto escalar y para resolver las aproximaciones

# %%
import math
import random

def scalar_prod(mask: int, word: int) -> int:
    """
    <mask, word> en GF(2) = paridad de (mask & word).
    Usa Speck.parity
    """
    return Speck.parity(mask & word)

def lin_form_plain_cipher(alpha0, beta0, alphaR, betaR, P, C):
    """
    Evalúa:
        <(alpha0, beta0), P> xor <(alphaR, betaR), C>
    donde P = (x0, y0), C = (xR, yR).

    Devuelve 0 si la ecuación lineal se cumple, 1 si no.
    """
    x0, y0 = P
    xR, yR = C

    in_part  = scalar_prod(alpha0, x0) ^ scalar_prod(beta0, y0)
    out_part = scalar_prod(alphaR, xR) ^ scalar_prod(betaR, yR)

    return in_part ^ out_part

def state_to_masks(state, word_size=16):
    uH, uL, vH, vL, b, phase = state
    half = word_size // 2
    mask8 = (1 << half) - 1

    u16 = ((uH & mask8) << half) | (uL & mask8)
    v16 = ((vH & mask8) << half) | (vL & mask8)
    return u16, v16

def best_path_for_masks(env: EnvHier8to16,
                        agent: QAgent,
                        u16: int,
                        v16: int,
                        K: int = 5,
                        depth: int = 8):
    s0 = masks_to_state(u16, v16, b=0, phase=0)

    if not env.actions(s0):
        return None

    greedy = rollout_greedy(env, agent, init_state=s0, max_steps=2 * env.R)
    best_path = greedy

    def make_env():
        return EnvHier8to16(env.P, env.S, rounds=env.R,
                            reward_mode=env.reward_mode, carry=env.carry)

    topk = beam_search_paths(make_env, agent, init_state=s0, K=K, depth=depth)
    if topk and topk[0].return_ > best_path.return_:
        best_path = topk[0]

    return best_path

# %% [markdown]
# ### Estimador del sesgo

# %%
def estimate_bias_for_approx(
    speck: Speck,
    rounds: int,      # nº de rondas de la aproximación
    alpha0: int,
    beta0: int,
    alphaR: int,
    betaR: int,
    N: int = 1 << 16,  # nº de pares
):
    """
    Ataque experimental tipo Matsui:
      - fija una clave aleatoria
      - genera N pares (P,C) con 'rounds' rondas
      - estima el sesgo de la ecuación lineal
    """
    # 1) Clave aleatoria
    key = [random.randrange(1 << speck.word_size) for _ in range(speck.n_main_key_words)]
    speck.key_schedule(key)

    n = speck.word_size
    count_zero = 0

    for _ in range(N):
        # Texto claro aleatorio
        P = (random.randrange(1 << n), random.randrange(1 << n))
        # Cifrado con 'rounds' rondas
        C = speck.encrypt(P, rounds=rounds)

        if lin_form_plain_cipher(alpha0, beta0, alphaR, betaR, P, C) == 0:
            count_zero += 1

    p   = count_zero / N
    eps = p - 0.5
    return eps, p

# %% [markdown]
# ### Ataque

# %%
rows_attack_ml = []

R = env.R
N_PAIRS = 1 << 16

df_seeds = df_matsui[["seed_idx", "seed_alpha0_dec", "seed_beta0_dec"]].drop_duplicates()
print("Nº de semillas únicas en df_matsui:", len(df_seeds))

n_no_actions = 0
n_no_steps   = 0

for _, row in df_seeds.iterrows():
    seed_idx = int(row["seed_idx"])
    u16_seed = int(row["seed_alpha0_dec"])
    v16_seed = int(row["seed_beta0_dec"])

    path = best_path_for_masks(env, agent, u16_seed, v16_seed, K=5, depth=8)

    if path is None:
        n_no_actions += 1
        # opcional: registrar igual la semilla
        rows_attack_ml.append({
            "method": "ml",
            "seed_idx": seed_idx,
            "seed_alpha0_hex": hex(u16_seed),
            "seed_beta0_hex":  hex(v16_seed),
            "alpha0_hex": None,
            "beta0_hex":  None,
            "alphaR_hex": None,
            "betaR_hex":  None,
            "cw_total_teorico_ml": 100.0,
            "return_ml": 0.0,
            "p_emp": None,
            "eps_emp": None,
            "cw_emp": 100.0,
        })
        continue

    if not path.steps:
        n_no_steps += 1
        # igual lo guardas con valores neutros
        rows_attack_ml.append({
            "method": "ml",
            "seed_idx": seed_idx,
            "seed_alpha0_hex": hex(u16_seed),
            "seed_beta0_hex":  hex(v16_seed),
            "alpha0_hex": None,
            "beta0_hex":  None,
            "alphaR_hex": None,
            "betaR_hex":  None,
            "cw_total_teorico_ml": 100.0,
            "return_ml": path.return_,
            "p_emp": None,
            "eps_emp": None,
            "cw_emp": 100.0,
        })
        continue

    # ---- caso normal: sí hubo camino ----
    s_start = path.steps[0].state
    s_end   = path.steps[-1].next_state

    alpha0_ml, beta0_ml = state_to_masks(s_start, word_size=speck.word_size)
    alphaR_ml, betaR_ml = state_to_masks(s_end,   word_size=speck.word_size)

    cw_total_ml = sum(
        step.info.get("cw_round", 0.0)
        for step in path.steps
        if isinstance(step.info, dict) and "cw_round" in step.info
    )

    eps_exp, p_exp = estimate_bias_for_approx(
        speck=speck,
        rounds=R,
        alpha0=alpha0_ml,
        beta0=beta0_ml,
        alphaR=alphaR_ml,
        betaR=betaR_ml,
        N=N_PAIRS,
    )

    cw_emp = -math.log2(abs(eps_exp)) if eps_exp != 0 else float("inf")

    rows_attack_ml.append({
        "method": "ml",
        "seed_idx": seed_idx,
        "seed_alpha0_hex": hex(u16_seed),
        "seed_beta0_hex":  hex(v16_seed),
        "alpha0_hex": hex(alpha0_ml),
        "beta0_hex":  hex(beta0_ml),
        "alphaR_hex": hex(alphaR_ml),
        "betaR_hex":  hex(betaR_ml),
        "cw_total_teorico_ml": cw_total_ml,
        "return_ml": path.return_,
        "p_emp": p_exp,
        "eps_emp": eps_exp,
        "cw_emp": cw_emp,
    })

df_attack_ml = pd.DataFrame(rows_attack_ml)
print("Semillas totales:", len(df_seeds))
print("Sin acciones:", n_no_actions, " / sin pasos:", n_no_steps)
print("Filas en df_attack_ml:", len(df_attack_ml))
# Out:
# Nº de semillas únicas en df_matsui: 1000
# Semillas totales: 1000
# Sin acciones: 678  / sin pasos: 0
# Filas en df_attack_ml: 1000

# %%
df_attack_ml["cw_total_teorico_ml"] = (
    df_attack_ml["cw_total_teorico_ml"]
    .replace([np.inf, -np.inf], 100.0)
)

# %%
df_attack_ml["cw_total_teorico_ml"].unique()
# Out:
# array([100.,   0.,   1.,   2.])

# %% [markdown]
# ### Gráfica de resultados

# %%
df_matsui["cw_total"] = (
    df_matsui["cw_total"]
    .replace([np.inf, -np.inf], 100.0)
)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 1) Mejor Cw de cada método por par de máscaras
best_matsui = (
    df_matsui
    .groupby(["seed_alpha0_hex", "seed_beta0_hex"])["cw_total"]
    .min()
    .reset_index()
    .rename(columns={"cw_total": "cw_matsui"})
)

best_rl = (
    df_attack_ml
    .groupby(["seed_alpha0_hex", "seed_beta0_hex"])["cw_total_teorico_ml"]
    .min()
    .reset_index()
    .rename(columns={"cw_total_teorico_ml": "cw_rl"})
)

# 2) Emparejar por máscaras iniciales
df_comp = best_matsui.merge(
    best_rl,
    on=["seed_alpha0_hex", "seed_beta0_hex"],
    how="inner",
)

# 3) Determinar ganador
cw_m = df_comp["cw_matsui"].to_numpy()
cw_r = df_comp["cw_rl"].to_numpy()

# Por defecto marcamos como Non-valid (luego iremos corrigiendo)
winner = np.full(len(df_comp), "Non-valid", dtype=object)

# --- AQUÍ cambia la lógica: 0 es válido, SOLO 100 es no válido ---
m_invalid = (cw_m == 100)
r_invalid = (cw_r == 100)

# Ambos no válidos (100,100) -> Non-valid (se queda así)
both_invalid = m_invalid & r_invalid

# Resto: al menos uno es válido
mask_rest = ~both_invalid

# Para comparar, tratamos los no válidos (100) como un número enorme
BIG = 10**9
m_eff = np.where(mask_rest & m_invalid, BIG, cw_m)
r_eff = np.where(mask_rest & r_invalid, BIG, cw_r)

# Gana el válido más pequeño (0 ahora es perfectamente válido)
winner[mask_rest & (r_eff < m_eff)] = "RL"
winner[mask_rest & (m_eff < r_eff)] = "Matsui"

# Empate real: ambos válidos (≠100) e iguales (0 incluido)
mask_tie_real = (
    mask_rest &
    ~m_invalid & ~r_invalid &
    (cw_m == cw_r)
)
winner[mask_tie_real] = "Tie"

df_comp["winner"] = winner

# 4) Estadísticas y porcentajes
counts = df_comp["winner"].value_counts()
total  = len(df_comp)

n_matsui   = counts.get("Matsui", 0)
n_rl       = counts.get("RL", 0)
n_tie      = counts.get("Tie", 0)
n_nonvalid = counts.get("Non-valid", 0)   # aquí solo caen los (100,100)

pct_matsui   = 100 * n_matsui / total
pct_rl       = 100 * n_rl / total
pct_tie      = 100 * n_tie / total
pct_nonvalid = 100 * n_nonvalid / total

print(f"Total semillas comparadas   : {total}")
print(f"Matsui mejor        : {n_matsui} ({pct_matsui:.2f}%)")
print(f"RL mejor            : {n_rl} ({pct_rl:.2f}%)")
print(f"Empate (válido)     : {n_tie} ({pct_tie:.2f}%)")
print(f"Non-valid (100,100) : {n_nonvalid} ({pct_nonvalid:.2f}%)")

# 5) Gráfico de barras
labels = ["Matsui", "RL", "Tie", "Non-valid"]
values = [n_matsui, n_rl, n_tie, n_nonvalid]
pcts   = [pct_matsui, pct_rl, pct_tie, pct_nonvalid]

plt.figure(figsize=(6,4))
bars = plt.bar(labels, values)

for bar, pct in zip(bars, pcts):
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + 5,
        f"{pct:.1f}%",
        ha="center", va="bottom", fontsize=9
    )

plt.ylabel("Número de semillas")
plt.title("Quién obtiene mejor Cw por semilla (cLAT sin podar)")
plt.ylim(0, total * 1.05)
plt.tight_layout()
plt.show()
# Out:
# Total semillas comparadas   : 1000
# Matsui mejor        : 6 (0.60%)
# RL mejor            : 322 (32.20%)
# Empate (válido)     : 0 (0.00%)
# Non-valid (100,100) : 672 (67.20%)

# %%
cuentas = df_comp['cw_matsui'] > df_comp['cw_rl']

# %%
cuentas.value_counts(True)
# Out:
# False    0.678
# True     0.322
# Name: proportion, dtype: float64

# %%
matsui_win = df_comp[df_comp["winner"] == "Matsui"]
matsui_win
# Out:
#     seed_alpha0_hex seed_beta0_hex  cw_matsui  cw_rl  winner
# 66           0x1d27           0xec        6.0  100.0  Matsui
# 203          0x3d0f           0xce        7.0  100.0  Matsui
# 477          0x801e           0xa5        6.0  100.0  Matsui
# 571          0x9843           0x79        5.0  100.0  Matsui
# 638          0xa675           0x9b        7.0  100.0  Matsui
# 920          0xe940           0x48        5.0  100.0  Matsui

# %%
matsui_win = df_comp[df_comp["winner"] == "RL"]
matsui_win
# Out:
#     seed_alpha0_hex seed_beta0_hex  cw_matsui  cw_rl winner
# 4            0x10bc         0x132f      100.0    0.0     RL
# 13           0x11c9         0x1a12      100.0    0.0     RL
# 27           0x1556         0x17c6      100.0    0.0     RL
# 29           0x162d         0x1ded      100.0    0.0     RL
# 49           0x1a47         0x1c4e      100.0    0.0     RL
# ..              ...            ...        ...    ...    ...
# 990          0xfcd8         0xba0d      100.0    0.0     RL
# 994          0xfe0a         0xc9a4      100.0    0.0     RL
# 995          0xfe3b         0xe285      100.0    0.0     RL
# 996          0xfea7         0xfd91      100.0    0.0     RL
# 999          0xffb7         0xbdca      100.0    0.0     RL
#
# [322 rows x 5 columns]

# %% [markdown]
# ### Máscara x = 0x0006 y y = 0x0000

# %%
df_matsui = pd.read_csv("matsui_from_0006_clat_full.csv")

# Asegurarnos de que alpha/beta sean enteros (no floats)
for col in ["alpha0", "beta0", "alphaR", "betaR",
            "seed_alpha0_dec", "seed_beta0_dec"]:
    # Fill NaN values with 0 before converting to int
    df_matsui[col] = df_matsui[col].fillna(300).astype(int)

df_matsui.head()
# Out:
#    seed_idx  seed_alpha0_dec  seed_beta0_dec seed_alpha0_hex seed_beta0_hex  \
# 0       451            28282             121          0x6e7a           0x79
# 1       836            65138              93          0xfe72           0x5d
# 2        32            60200             180          0xeb28           0xb4
# 3       847            31087             237          0x796f           0xed
# 4       627             6034             102          0x1792           0x66
#
#    alpha0  beta0  alphaR  betaR alpha0_hex beta0_hex alphaR_hex betaR_hex  \
# 0   28282    121       1      1     0x6e7a      0x79        0x1       0x1
# 1   65138     93       1      1     0xfe72      0x5d        0x1       0x1
# 2   60200    180       0      0     0xeb28      0xb4        0x0       0x0
# 3   31087    237       1      1     0x796f      0xed        0x1       0x1
# 4    6034    102       0      0     0x1792      0x66        0x0       0x0
#
#    cw_total
# 0       5.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       7.0

# %%
df_matsui["cw_total"].unique()
# Out:
# array([ 5.,  6.,  7., inf])

# %% [markdown]
# ### Ataque

# %%
rows_attack_ml = []

R = env.R
N_PAIRS = 1 << 16

df_seeds = df_matsui[["seed_idx", "seed_alpha0_dec", "seed_beta0_dec"]].drop_duplicates()
print("Nº de semillas únicas en df_matsui:", len(df_seeds))

n_no_actions = 0
n_no_steps   = 0

for _, row in df_seeds.iterrows():
    seed_idx = int(row["seed_idx"])
    u16_seed = int(row["seed_alpha0_dec"])
    v16_seed = int(row["seed_beta0_dec"])

    path = best_path_for_masks(env, agent, u16_seed, v16_seed, K=5, depth=8)

    if path is None:
        n_no_actions += 1
        # opcional: registrar igual la semilla
        rows_attack_ml.append({
            "method": "ml",
            "seed_idx": seed_idx,
            "seed_alpha0_hex": hex(u16_seed),
            "seed_beta0_hex":  hex(v16_seed),
            "alpha0_hex": None,
            "beta0_hex":  None,
            "alphaR_hex": None,
            "betaR_hex":  None,
            "cw_total_teorico_ml": 100.0,
            "return_ml": 0.0,
            "p_emp": None,
            "eps_emp": None,
            "cw_emp": 100.0,
        })
        continue

    if not path.steps:
        n_no_steps += 1
        # igual lo guardas con valores neutros
        rows_attack_ml.append({
            "method": "ml",
            "seed_idx": seed_idx,
            "seed_alpha0_hex": hex(u16_seed),
            "seed_beta0_hex":  hex(v16_seed),
            "alpha0_hex": None,
            "beta0_hex":  None,
            "alphaR_hex": None,
            "betaR_hex":  None,
            "cw_total_teorico_ml": 100.0,
            "return_ml": path.return_,
            "p_emp": None,
            "eps_emp": None,
            "cw_emp": 100.0,
        })
        continue

    # ---- caso normal: sí hubo camino ----
    s_start = path.steps[0].state
    s_end   = path.steps[-1].next_state

    alpha0_ml, beta0_ml = state_to_masks(s_start, word_size=speck.word_size)
    alphaR_ml, betaR_ml = state_to_masks(s_end,   word_size=speck.word_size)

    cw_total_ml = sum(
        step.info.get("cw_round", 0.0)
        for step in path.steps
        if isinstance(step.info, dict) and "cw_round" in step.info
    )

    eps_exp, p_exp = estimate_bias_for_approx(
        speck=speck,
        rounds=R,
        alpha0=alpha0_ml,
        beta0=beta0_ml,
        alphaR=alphaR_ml,
        betaR=betaR_ml,
        N=N_PAIRS,
    )

    cw_emp = -math.log2(abs(eps_exp)) if eps_exp != 0 else float("inf")

    rows_attack_ml.append({
        "method": "ml",
        "seed_idx": seed_idx,
        "seed_alpha0_hex": hex(u16_seed),
        "seed_beta0_hex":  hex(v16_seed),
        "alpha0_hex": hex(alpha0_ml),
        "beta0_hex":  hex(beta0_ml),
        "alphaR_hex": hex(alphaR_ml),
        "betaR_hex":  hex(betaR_ml),
        "cw_total_teorico_ml": cw_total_ml,
        "return_ml": path.return_,
        "p_emp": p_exp,
        "eps_emp": eps_exp,
        "cw_emp": cw_emp,
    })

df_attack_ml = pd.DataFrame(rows_attack_ml)
print("Semillas totales:", len(df_seeds))
print("Sin acciones:", n_no_actions, " / sin pasos:", n_no_steps)
print("Filas en df_attack_ml:", len(df_attack_ml))
# Out:
# Nº de semillas únicas en df_matsui: 1000
# Semillas totales: 1000
# Sin acciones: 651  / sin pasos: 0
# Filas en df_attack_ml: 1000

# %%
df_attack_ml["cw_total_teorico_ml"] = (
    df_attack_ml["cw_total_teorico_ml"]
    .replace([np.inf, -np.inf], 100.0)
)

# %% [markdown]
# ### Gráfica de resultados

# %%
df_matsui["cw_total"] = (
    df_matsui["cw_total"]
    .replace([np.inf, -np.inf], 100.0)
)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 1) Mejor Cw de cada método por par de máscaras
best_matsui = (
    df_matsui
    .groupby(["seed_alpha0_hex", "seed_beta0_hex"])["cw_total"]
    .min()
    .reset_index()
    .rename(columns={"cw_total": "cw_matsui"})
)

best_rl = (
    df_attack_ml
    .groupby(["seed_alpha0_hex", "seed_beta0_hex"])["cw_total_teorico_ml"]
    .min()
    .reset_index()
    .rename(columns={"cw_total_teorico_ml": "cw_rl"})
)

# 2) Emparejar por máscaras iniciales
df_comp = best_matsui.merge(
    best_rl,
    on=["seed_alpha0_hex", "seed_beta0_hex"],
    how="inner",
)

# 3) Determinar ganador
cw_m = df_comp["cw_matsui"].to_numpy()
cw_r = df_comp["cw_rl"].to_numpy()

# Por defecto marcamos como Non-valid (luego iremos corrigiendo)
winner = np.full(len(df_comp), "Non-valid", dtype=object)

# --- AQUÍ cambia la lógica: 0 es válido, SOLO 100 es no válido ---
m_invalid = (cw_m == 100)
r_invalid = (cw_r == 100)

# Ambos no válidos (100,100) -> Non-valid (se queda así)
both_invalid = m_invalid & r_invalid

# Resto: al menos uno es válido
mask_rest = ~both_invalid

# Para comparar, tratamos los no válidos (100) como un número enorme
BIG = 10**9
m_eff = np.where(mask_rest & m_invalid, BIG, cw_m)
r_eff = np.where(mask_rest & r_invalid, BIG, cw_r)

# Gana el válido más pequeño (0 ahora es perfectamente válido)
winner[mask_rest & (r_eff < m_eff)] = "RL"
winner[mask_rest & (m_eff < r_eff)] = "Matsui"

# Empate real: ambos válidos (≠100) e iguales (0 incluido)
mask_tie_real = (
    mask_rest &
    ~m_invalid & ~r_invalid &
    (cw_m == cw_r)
)
winner[mask_tie_real] = "Tie"

df_comp["winner"] = winner

# 4) Estadísticas y porcentajes
counts = df_comp["winner"].value_counts()
total  = len(df_comp)

n_matsui   = counts.get("Matsui", 0)
n_rl       = counts.get("RL", 0)
n_tie      = counts.get("Tie", 0)
n_nonvalid = counts.get("Non-valid", 0)   # aquí solo caen los (100,100)

pct_matsui   = 100 * n_matsui / total
pct_rl       = 100 * n_rl / total
pct_tie      = 100 * n_tie / total
pct_nonvalid = 100 * n_nonvalid / total

print(f"Total semillas comparadas   : {total}")
print(f"Matsui mejor        : {n_matsui} ({pct_matsui:.2f}%)")
print(f"RL mejor            : {n_rl} ({pct_rl:.2f}%)")
print(f"Empate (válido)     : {n_tie} ({pct_tie:.2f}%)")
print(f"Non-valid (100,100) : {n_nonvalid} ({pct_nonvalid:.2f}%)")

# 5) Gráfico de barras
labels = ["Matsui", "RL", "Tie", "Non-valid"]
values = [n_matsui, n_rl, n_tie, n_nonvalid]
pcts   = [pct_matsui, pct_rl, pct_tie, pct_nonvalid]

plt.figure(figsize=(6,4))
bars = plt.bar(labels, values)

for bar, pct in zip(bars, pcts):
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + 5,
        f"{pct:.1f}%",
        ha="center", va="bottom", fontsize=9
    )

plt.ylabel("Número de semillas")
plt.title("Quién obtiene mejor Cw por semilla (cLAT sin podar)")
plt.ylim(0, total * 1.05)
plt.tight_layout()
plt.show()
# Out:
# Total semillas comparadas   : 1000
# Matsui mejor        : 7 (0.70%)
# RL mejor            : 349 (34.90%)
# Empate (válido)     : 0 (0.00%)
# Non-valid (100,100) : 644 (64.40%)

# %%
s0 = (78, 189, 82, 57, 0, 0)

# Ver las Q para ese estado
print("Q(s0) =", agent.Q.get(s0))
print("Acciones posibles desde s0:", env.actions(s0))
# Out:
# Q(s0) = None
# Acciones posibles desde s0: [90, 91, 92, 93, 94]

# %% [markdown]
# ## Key Recovery Attack Matsui 1

# %% [markdown]
# ### Utilities

# %%
# --------- bit utils ----------
def popcount(x: int) -> int:
    return int(x).bit_count()

def hamming_masked(a: int, b: int, mask: int) -> int:
    return popcount((a ^ b) & mask)

# --------- rol/ror uint16 ----------
def rol16(x: np.ndarray, r: int) -> np.ndarray:
    x = x.astype(np.uint16, copy=False)
    return np.uint16(((x << r) & 0xFFFF) | (x >> (16 - r)))

def ror16(x: np.ndarray, r: int) -> np.ndarray:
    x = x.astype(np.uint16, copy=False)
    return np.uint16((x >> r) | ((x << (16 - r)) & 0xFFFF))

# --------- Speck16 encrypt (vectorizado) ----------
def speck_encrypt_vec(x: np.ndarray, y: np.ndarray, round_keys_u16: np.ndarray, alpha=7, beta=2) -> tuple[np.ndarray, np.ndarray]:
    """
    x,y: np.uint16 arrays
    round_keys_u16: shape (R,) uint16
    """
    x = x.astype(np.uint16, copy=False)
    y = y.astype(np.uint16, copy=False)
    for k in round_keys_u16:
        x = ror16(x, alpha)
        x = np.uint16((x + y) & 0xFFFF)
        x = np.uint16(x ^ np.uint16(k))
        y = rol16(y, beta)
        y = np.uint16(y ^ x)
    return x, y

# --------- paridad vectorizada (tabla 8-bit) ----------
_PAR8 = np.array([bin(i).count("1") & 1 for i in range(256)], dtype=np.uint8)

def parity16_arr(z: np.ndarray) -> np.ndarray:
    z = z.astype(np.uint16, copy=False)
    lo = (z & 0xFF).astype(np.uint8)
    hi = ((z >> 8) & 0xFF).astype(np.uint8)
    return _PAR8[lo] ^ _PAR8[hi]

def parity_mask_arr(word_u16: np.ndarray, mask_u16: int) -> np.ndarray:
    return parity16_arr(np.uint16(word_u16 & np.uint16(mask_u16)))

# --------- key guesses over bit positions ----------
def gen_key_guesses_from_mask(mask_u16: int) -> np.ndarray:
    bitpos = [i for i in range(16) if (mask_u16 >> i) & 1]
    k = len(bitpos)
    if k == 0:
        raise ValueError("Máscara de key-guess tiene 0 bits (mask_u16=0).")
    guesses = np.zeros((1 << k,), dtype=np.uint16)
    for g in range(1 << k):
        val = 0
        for j, pos in enumerate(bitpos):
            if (g >> j) & 1:
                val |= (1 << pos)
        guesses[g] = np.uint16(val)
    return guesses

# --------- scoring tipo Matsui-1 "keyed" última ronda (vectorizado en pares) ----------
def matsui1_last_round_rank_vec(
    x1: np.ndarray,
    y1: np.ndarray,
    ax: int,
    ay: int,
    gx: int,
    gy_prime: int = 0,
    w_last: int | None = None,
    alpha=7,
    beta=2
):
    """
    Implementa:
    - x1,y1: ciphertext arrays (uint16)
    - se adivina kw solo en bits de w_last (si None -> gx)
    Retorna: ranked list [(key_guess_u16, score_int), ...] score = |#0 - #1|
    """
    if w_last is None:
        w_last = gx
    w_last = int(w_last) & 0xFFFF
    if w_last == 0:
        raise ValueError("w_last=0: no hay bits de clave para adivinar.")

    key_guesses = gen_key_guesses_from_mask(w_last)  # uint16 array

    # precomputes
    x1 = x1.astype(np.uint16, copy=False)
    y1 = y1.astype(np.uint16, copy=False)

    # y = ROR(y1 ^ x1, beta)
    y = ror16(np.uint16(y1 ^ x1), beta)

    px1 = parity_mask_arr(x1, gx)
    py1 = parity_mask_arr(y1, gy_prime)
    py  = parity_mask_arr(y,  ay)

    ranked = []
    for kg in key_guesses:
        # partial decrypt last round up to after_rol_alpha
        x = np.uint16(x1 ^ kg)
        x = np.uint16((x - y) & 0xFFFF)
        x = rol16(x, alpha)

        px  = parity_mask_arr(x, ax)
        lhs = px ^ py ^ px1 ^ py1  # 0/1 array

        # bias_counter = sum(+1 si lhs==0, -1 si lhs==1) = sum(1 - 2*lhs)
        score = int(np.abs(np.sum(1 - 2 * lhs.astype(np.int32))))
        ranked.append((int(kg), score))

    ranked.sort(key=lambda kv: kv[1], reverse=True)
    return ranked

# %% [markdown]
# ### Masks Utlities

# %%
def last_round_masks_from_path(path, R: int, word_size=16):
    """
    Retorna (ax, ay, gx, gy, w_last_mask)
    - (ax,ay): máscaras de entrada a la última ronda
    - (gx,gy): máscaras de salida (ciphertext) después de la última ronda
    - w_last_mask: bits de subkey a adivinar (si step.info trae 'w16', usa eso; si no, usa gx)
    """
    if path is None or not getattr(path, "steps", None):
        return None

    steps = path.steps
    idx_in = 2 * (R - 1)
    if idx_in >= len(steps):
        return None

    s_in  = steps[idx_in].state
    s_out = steps[-1].next_state

    ax, ay = state_to_masks(s_in,  word_size=word_size)
    gx, gy = state_to_masks(s_out, word_size=word_size)

    w_last = steps[-1].info.get("w16", gx) if hasattr(steps[-1], "info") else gx
    w_last = int(w_last) & 0xFFFF

    return int(ax), int(ay), int(gx), int(gy), int(w_last)

# %% [markdown]
# ### Código para correr el ataque

# %%
def run_key_recovery_for_paths(
    paths: list,
    speck_obj,
    R: int,
    n_pairs: int = 1 << 14,
    trials_per_path: int = 50,
    top_k: int = 5,
    max_guess_bits: int = 10,
    seed: int = 2025
):
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt

    # ---------- helpers ----------
    def error_bit_positions_masked(k_guess: int, k_true: int, w_mask: int, word_size: int = 16):
        diff = (k_guess ^ k_true) & w_mask
        return [i for i in range(word_size) if (diff >> i) & 1]

    def first_round_masks_from_path(path):
        """
        Intenta extraer las máscaras iniciales (ax0, ay0) del path.
        Devuelve (ax0, ay0) o (None, None) si no se puede inferir.
        """
        # Caso 1: PathLog con .steps
        if hasattr(path, "steps") and path.steps:
            s0 = path.steps[0]

            # a) state como tupla/lista
            if hasattr(s0, "state") and s0.state is not None:
                st = s0.state
                if isinstance(st, (tuple, list)) and len(st) >= 2:
                    return int(st[0]), int(st[1])
                if isinstance(st, dict):
                    for kx, ky in [("ax", "ay"), ("x", "y"), ("xmask", "ymask"), ("mx", "my")]:
                        if kx in st and ky in st:
                            return int(st[kx]), int(st[ky])

            # b) info dict
            if hasattr(s0, "info") and isinstance(s0.info, dict):
                for kx, ky in [("ax", "ay"), ("x", "y"), ("xmask", "ymask"), ("mx", "my")]:
                    if kx in s0.info and ky in s0.info:
                        return int(s0.info[kx]), int(s0.info[ky])

        # Caso 2: path como lista/tupla de steps
        if isinstance(path, (list, tuple)) and len(path) > 0:
            s0 = path[0]
            # step como tupla/lista (ax, ay, ...)
            if isinstance(s0, (tuple, list)) and len(s0) >= 2:
                if all(isinstance(z, (int, np.integer)) for z in s0[:2]):
                    return int(s0[0]), int(s0[1])
            # step como dict
            if isinstance(s0, dict):
                for kx, ky in [("ax", "ay"), ("x", "y"), ("xmask", "ymask"), ("mx", "my")]:
                    if kx in s0 and ky in s0:
                        return int(s0[kx]), int(s0[ky])

        return None, None

    def add_hex_columns(df, cols, word_size):
        mask = (1 << word_size) - 1
        for c in cols:
            if c in df.columns:
                df[c + "_hex"] = df[c].apply(
                    lambda v: None if pd.isna(v) else f"0x{(int(v) & mask):0{word_size//4}x}"
                )

    # ---------- main ----------
    rng = np.random.default_rng(seed)
    rows = []
    err_rows = []

    FULL_MASK = (1 << speck_obj.word_size) - 1

    for pi, path in enumerate(paths):
        masks = last_round_masks_from_path(path, R=R, word_size=speck_obj.word_size)
        if masks is None:
            continue

        # NUEVO: máscaras iniciales (origen del path)
        ax0, ay0 = first_round_masks_from_path(path)

        ax, ay, gx, gy, w_last = masks
        w_last = int(w_last) & FULL_MASK
        kbits = popcount(w_last)

        # evita explosión: 2^(kbits) guesses
        if kbits == 0 or kbits > max_guess_bits:
            continue

        for t in range(trials_per_path):
            # --- key random (m palabras de word_size bits) ---
            key_words = [
                int(rng.integers(0, 1 << speck_obj.word_size, dtype=np.uint16))
                for _ in range(speck_obj.n_main_key_words)
            ]
            rk = speck_obj.key_schedule(key_words)  # shape (R,1) en tu implementación
            rk_u16 = np.array([int(rk[i][0]) for i in range(R)], dtype=np.uint16)
            true_last = int(rk_u16[-1]) & FULL_MASK

            # --- pares P/C ---
            x0p = rng.integers(0, 1 << speck_obj.word_size, size=n_pairs, dtype=np.uint16)
            y0p = rng.integers(0, 1 << speck_obj.word_size, size=n_pairs, dtype=np.uint16)
            xR, yR = speck_encrypt_vec(x0p, y0p, rk_u16, alpha=speck_obj.alpha, beta=speck_obj.beta)

            ranked = matsui1_last_round_rank_vec(
                x1=xR, y1=yR,
                ax=ax, ay=ay,
                gx=gx, gy_prime=gy,
                w_last=w_last,
                alpha=speck_obj.alpha, beta=speck_obj.beta
            )

            true_partial = true_last & w_last

            # top-1
            best_guess = int(ranked[0][0]) & FULL_MASK
            bit_errors_top1 = int(hamming_masked(best_guess, true_last, w_last))
            success_top1 = (bit_errors_top1 == 0)

            # rank del verdadero (por bits relevantes)
            rank_true = None
            for i, (kg, sc) in enumerate(ranked):
                if (int(kg) & w_last) == true_partial:
                    rank_true = i + 1
                    break

            success_topk = (rank_true is not None and rank_true <= top_k)

            # errores detallados (solo en bits w_last)
            error_mask = int((best_guess ^ true_last) & w_last)
            error_positions = error_bit_positions_masked(
                best_guess, true_last, w_last, word_size=speck_obj.word_size
            )

            rows.append({
                "path_idx": int(pi),
                "trial": int(t),

                # NUEVO: origen del path
                "ax0": ax0,
                "ay0": ay0,

                # máscaras última ronda
                "ax": int(ax), "ay": int(ay),
                "gx": int(gx), "gy": int(gy),

                "w_last": int(w_last),
                "guess_bits": int(kbits),
                "n_pairs": int(n_pairs),

                "true_last": int(true_last),
                "best_guess": int(best_guess),

                "bit_errors_top1": int(bit_errors_top1),
                "success_top1": bool(success_top1),

                "rank_true": rank_true,
                "success_topk": bool(success_topk),
            })

            if not success_top1:
                err_rows.append({
                    "path_idx": int(pi),
                    "trial": int(t),

                    # NUEVO: origen del path
                    "ax0": ax0,
                    "ay0": ay0,

                    "w_last": int(w_last),
                    "guess_bits": int(kbits),

                    "true_last": int(true_last),
                    "best_guess": int(best_guess),

                    "bit_errors_top1": int(bit_errors_top1),
                    "error_mask": error_mask,
                    "error_positions": error_positions,
                })

    df = pd.DataFrame(rows)
    df_errbits = pd.DataFrame(err_rows)

    if df.empty:
        print("No salió ningún experimento (revisa paths, R, o baja max_guess_bits / sube n_pairs).")
        return df, df_errbits

    # Añadir columnas hex (más legible)
    add_hex_columns(
        df,
        cols=["ax0", "ay0", "ax", "ay", "gx", "gy", "w_last", "true_last", "best_guess"],
        word_size=speck_obj.word_size
    )
    add_hex_columns(
        df_errbits,
        cols=["ax0", "ay0", "w_last", "true_last", "best_guess", "error_mask"],
        word_size=speck_obj.word_size
    )

    # --- resumen ---
    total = len(df)
    s1 = int(df["success_top1"].sum())
    sk = int(df["success_topk"].sum())

    print(f"Experimentos: {total}")
    print(f"Aciertos top-1: {s1}  ({100*s1/total:.2f}%)")
    print(f"Aciertos top-{top_k}: {sk} ({100*sk/total:.2f}%)")

    # near-miss report: ≤1, ≤2, ≤3 bits mal
    for thr in [1, 2, 3]:
        frac = float((df["bit_errors_top1"] <= thr).mean())
        print(f"Top-1 con ≤{thr} bit(s) mal: {int(frac*total)} ({100*frac:.2f}%)")

    # distribución de errores en desaciertos
    misses = df[~df["success_top1"]]
    if not misses.empty:
        dist = misses["bit_errors_top1"].value_counts().sort_index()
        print("\nDesaciertos (top-1) - distribución de bits equivocados (solo en w_last):")
        print(dist)

        dist.plot(kind="bar")
        plt.xlabel("# bits equivocados (en w_last)")
        plt.ylabel("conteo")
        plt.title("Distribución de errores en desaciertos (top-1)")
        plt.tight_layout()
        plt.show()

    return df, df_errbits

# %%
df_ok = df_attack_ml.dropna(subset=["alpha0_hex", "beta0_hex"]).copy()

paths_validos = []
for _, r in df_ok.iterrows():
    a0 = int(r["alpha0_hex"], 0)
    b0 = int(r["beta0_hex"], 0)
    p = best_path_for_masks(env, agent, a0, b0, K=16, depth=2*env.R)
    if p is not None and getattr(p, "steps", None):
        paths_validos.append(p)

df_results, df_errors = run_key_recovery_for_paths(paths_validos, speck, env.R)
# Out:
# No salió ningún experimento (revisa paths, R, o baja max_guess_bits / sube n_pairs).

# %%
df_errors.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
s = env.reset(init_state=s0)

a0 = env.actions(s)[0]
s1, r1, done1, info1 = env.step(a0)
print("step0:", done1, info1, "s1:", s1)

s1
# Out:
# step0: False {'phase': 'lo'} s1: (78, 189, 82, 57, 0, 1)
# (78, 189, 82, 57, 0, 1)

# %%
a1 = env.actions(s1)
a1
# Out:
# []

# %%
acts = env.actions(s1)
if len(acts) == 0:
    # dead-end: no hay continuación desde este estado
    # marca done y registra razón
    done = True
    info = {"error": "no_actions"}

acts
# Out:
# []

# %%
a1 = env.actions(s1)[0]
s2, r2, done2, info2 = env.step(a1)
print("step1:", done2, info2, "s2:", s2)

# %%
paths_validos
# Out:
# [PathLog(steps=[StepLog(t=0, state=(21, 50, 17, 190, 0, 0), action=20, reward=0.0, next_state=(21, 50, 17, 190, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(17, 0.0), (20, 0.0), (21, 0.0), (23, 0.0)]), StepLog(t=1, state=(21, 50, 17, 190, 0, 1), action=None, reward=0.0, next_state=(21, 50, 17, 190, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(109, 248, 80, 147, 0, 0), action=124, reward=0.0, next_state=(109, 248, 80, 147, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(124, 0.0), (125, 0.0)]), StepLog(t=1, state=(109, 248, 80, 147, 0, 1), action=218, reward=0.5, next_state=(180, 249, 62, 151, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 31962}, q_values=[(218, 0.0), (219, 0.0), (234, 0.0), (235, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(225, 141, 245, 78, 0, 0), action=149, reward=0.0, next_state=(225, 141, 245, 78, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(145, 0.0), (148, 0.0), (149, 0.0), (151, 0.0), (241, 0.0), (244, 0.0), (245, 0.0), (247, 0.0)]), StepLog(t=1, state=(225, 141, 245, 78, 0, 1), action=None, reward=0.0, next_state=(225, 141, 245, 78, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(143, 185, 180, 90, 0, 0), action=182, reward=0.0, next_state=(143, 185, 180, 90, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(182, 0.0), (183, 0.0), (186, 0.0), (187, 0.0)]), StepLog(t=1, state=(143, 185, 180, 90, 0, 1), action=None, reward=0.0, next_state=(143, 185, 180, 90, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(160, 254, 161, 168, 0, 0), action=128, reward=0.0, next_state=(160, 254, 161, 168, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(128, 0.0), (129, 0.0), (224, 0.0), (225, 0.0)]), StepLog(t=1, state=(160, 254, 161, 168, 0, 1), action=215, reward=0.5, next_state=(175, 1, 6, 117, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 32983}, q_values=[(172, 0.0), (174, 0.0), (175, 0.0), (180, 0.0), (182, 0.0), (183, 0.0), (204, 0.0), (206, 0.0), (207, 0.0), (212, 0.0), (214, 0.0), (215, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(139, 103, 129, 216, 0, 0), action=139, reward=0.0, next_state=(139, 103, 129, 216, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(137, 0.0), (138, 0.0), (139, 0.0)]), StepLog(t=1, state=(139, 103, 129, 216, 0, 1), action=None, reward=0.0, next_state=(139, 103, 129, 216, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(203, 232, 160, 187, 0, 0), action=234, reward=0.0, next_state=(203, 232, 160, 187, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(234, 0.0), (235, 0.0)]), StepLog(t=1, state=(203, 232, 160, 187, 0, 1), action=170, reward=0.5, next_state=(85, 213, 104, 68, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 60074}, q_values=[(170, 0.0), (171, 0.0), (178, 0.0), (179, 0.0), (202, 0.0), (203, 0.0), (210, 0.0), (211, 0.0)]), StepLog(t=2, state=(85, 213, 104, 68, 0, 0), action=125, reward=0.0, next_state=(85, 213, 104, 68, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(124, 0.0), (125, 0.0)]), StepLog(t=3, state=(85, 213, 104, 68, 0, 1), action=None, reward=0.0, next_state=(85, 213, 104, 68, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(52, 208, 63, 20, 0, 0), action=42, reward=0.0, next_state=(52, 208, 63, 20, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(38, 0.0), (39, 0.0), (42, 0.0), (43, 0.0)]), StepLog(t=1, state=(52, 208, 63, 20, 0, 1), action=None, reward=0.0, next_state=(52, 208, 63, 20, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(205, 199, 180, 20, 0, 0), action=244, reward=0.0, next_state=(205, 199, 180, 20, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(244, 0.0), (245, 0.0), (248, 0.0), (249, 0.0)]), StepLog(t=1, state=(205, 199, 180, 20, 0, 1), action=None, reward=0.0, next_state=(205, 199, 180, 20, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(138, 141, 203, 205, 0, 0), action=216, reward=0.0, next_state=(138, 141, 203, 205, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(136, 0.0), (137, 0.0), (142, 0.0), (143, 0.0), (192, 0.0), (193, 0.0), (198, 0.0), (199, 0.0), (202, 0.0), (203, 0.0), (216, 0.0), (217, 0.0), (222, 0.0), (223, 0.0), (232, 0.0), (233, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(138, 141, 203, 205, 0, 1), action=193, reward=0.5, next_state=(131, 177, 247, 246, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 55489}, q_values=[(136, 0.0), (137, 0.0), (139, 0.0), (141, 0.0), (192, 0.0), (193, 0.0), (195, 0.0), (197, 0.0), (204, 0.0), (205, 0.0), (207, 0.0), (216, 0.0), (217, 0.0), (219, 0.0), (221, 0.0), (232, 0.0), (233, 0.0), (235, 0.0), (237, 0.0)]), StepLog(t=2, state=(131, 177, 247, 246, 0, 0), action=245, reward=0.0, next_state=(131, 177, 247, 246, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(242, 0.0), (243, 0.0), (244, 0.0), (245, 0.0), (247, 0.0)]), StepLog(t=3, state=(131, 177, 247, 246, 0, 1), action=247, reward=0.25, next_state=(239, 235, 42, 44, 0, 0), done=True, info={'cw_round': 1, 'bias_round': 0.25, 'w16': 62967}, q_values=[(166, 0.0), (167, 0.0), (198, 0.0), (199, 0.0), (246, 0.0), (247, 0.0)])], return_=0.75),
#  PathLog(steps=[StepLog(t=0, state=(201, 1, 143, 136, 0, 0), action=239, reward=0.0, next_state=(201, 1, 143, 136, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(141, 0.0), (142, 0.0), (143, 0.0), (197, 0.0), (198, 0.0), (199, 0.0), (221, 0.0), (222, 0.0), (223, 0.0), (237, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(201, 1, 143, 136, 0, 1), action=None, reward=0.0, next_state=(201, 1, 143, 136, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(158, 58, 197, 194, 0, 0), action=215, reward=0.0, next_state=(158, 58, 197, 194, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(214, 0.0), (215, 0.0), (218, 0.0), (219, 0.0)]), StepLog(t=1, state=(158, 58, 197, 194, 0, 1), action=None, reward=0.0, next_state=(158, 58, 197, 194, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(124, 251, 118, 48, 0, 0), action=68, reward=0.0, next_state=(124, 251, 118, 48, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(68, 0.0), (70, 0.0), (71, 0.0), (72, 0.0), (74, 0.0), (75, 0.0), (116, 0.0), (118, 0.0), (119, 0.0), (120, 0.0), (122, 0.0), (123, 0.0)]), StepLog(t=1, state=(124, 251, 118, 48, 0, 1), action=None, reward=0.0, next_state=(124, 251, 118, 48, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(243, 54, 203, 200, 0, 0), action=185, reward=0.0, next_state=(243, 54, 203, 200, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(178, 0.0), (179, 0.0), (184, 0.0), (185, 0.0), (187, 0.0), (190, 0.0), (191, 0.0)]), StepLog(t=1, state=(243, 54, 203, 200, 0, 1), action=None, reward=0.0, next_state=(243, 54, 203, 200, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(21, 213, 29, 41, 0, 0), action=27, reward=0.0, next_state=(21, 213, 29, 41, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(20, 0.0), (21, 0.0), (23, 0.0), (24, 0.0), (25, 0.0), (27, 0.0), (29, 0.0)]), StepLog(t=1, state=(21, 213, 29, 41, 0, 1), action=None, reward=0.0, next_state=(21, 213, 29, 41, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(155, 57, 177, 39, 0, 0), action=155, reward=0.0, next_state=(155, 57, 177, 39, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(153, 0.0), (154, 0.0), (155, 0.0), (169, 0.0), (170, 0.0), (171, 0.0)]), StepLog(t=1, state=(155, 57, 177, 39, 0, 1), action=63, reward=0.5, next_state=(127, 54, 95, 161, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 39743}, q_values=[(61, 0.0), (62, 0.0), (63, 0.0)]), StepLog(t=2, state=(127, 54, 95, 161, 0, 0), action=80, reward=0.0, next_state=(127, 54, 95, 161, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(80, 0.0), (81, 0.0), (83, 0.0), (86, 0.0), (87, 0.0), (92, 0.0), (93, 0.0), (95, 0.0), (96, 0.0), (97, 0.0), (99, 0.0), (102, 0.0), (103, 0.0), (108, 0.0), (109, 0.0), (111, 0.0), (120, 0.0), (121, 0.0), (123, 0.0), (126, 0.0), (127, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(124, 191, 91, 41, 0, 0), action=102, reward=0.0, next_state=(124, 191, 91, 41, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(86, 0.0), (87, 0.0), (102, 0.0), (103, 0.0), (126, 0.0), (127, 0.0)]), StepLog(t=1, state=(124, 191, 91, 41, 0, 1), action=None, reward=0.0, next_state=(124, 191, 91, 41, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(221, 4, 161, 247, 0, 0), action=255, reward=0.0, next_state=(221, 4, 161, 247, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(249, 0.0), (252, 0.0), (253, 0.0), (255, 0.0)]), StepLog(t=1, state=(221, 4, 161, 247, 0, 1), action=None, reward=0.0, next_state=(221, 4, 161, 247, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(231, 245, 169, 234, 0, 0), action=175, reward=0.0, next_state=(231, 245, 169, 234, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(173, 0.0), (174, 0.0), (175, 0.0), (205, 0.0), (206, 0.0), (207, 0.0)]), StepLog(t=1, state=(231, 245, 169, 234, 0, 1), action=158, reward=0.5, next_state=(61, 95, 8, 52, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 44958}, q_values=[(158, 0.0), (159, 0.0), (254, 0.0), (255, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(162, 113, 251, 77, 0, 0), action=222, reward=0.0, next_state=(162, 113, 251, 77, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(178, 0.0), (179, 0.0), (184, 0.0), (185, 0.0), (190, 0.0), (191, 0.0), (210, 0.0), (211, 0.0), (216, 0.0), (217, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(162, 113, 251, 77, 0, 1), action=125, reward=0.5, next_state=(251, 188, 51, 74, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 56957}, q_values=[(121, 0.0), (124, 0.0), (125, 0.0), (127, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(248, 151, 169, 219, 0, 0), action=168, reward=0.0, next_state=(248, 151, 169, 219, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(168, 0.0), (169, 0.0), (176, 0.0), (177, 0.0), (200, 0.0), (201, 0.0), (208, 0.0), (209, 0.0)]), StepLog(t=1, state=(248, 151, 169, 219, 0, 1), action=155, reward=0.5, next_state=(55, 81, 15, 245, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 43163}, q_values=[(154, 0.0), (155, 0.0), (156, 0.0), (157, 0.0), (159, 0.0), (202, 0.0), (203, 0.0), (204, 0.0), (205, 0.0), (207, 0.0), (250, 0.0), (251, 0.0), (252, 0.0), (253, 0.0), (255, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(240, 110, 249, 11, 0, 0), action=137, reward=0.0, next_state=(240, 110, 249, 11, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(136, 0.0), (137, 0.0), (184, 0.0), (185, 0.0), (232, 0.0), (233, 0.0)]), StepLog(t=1, state=(240, 110, 249, 11, 0, 1), action=None, reward=0.0, next_state=(240, 110, 249, 11, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(171, 67, 205, 33, 0, 0), action=255, reward=0.0, next_state=(171, 67, 205, 33, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(205, 0.0), (206, 0.0), (207, 0.0), (229, 0.0), (230, 0.0), (231, 0.0), (253, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(171, 67, 205, 33, 0, 1), action=None, reward=0.0, next_state=(171, 67, 205, 33, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(158, 128, 208, 147, 0, 0), action=156, reward=0.0, next_state=(158, 128, 208, 147, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(156, 0.0), (158, 0.0), (159, 0.0), (204, 0.0), (206, 0.0), (207, 0.0), (252, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(158, 128, 208, 147, 0, 1), action=146, reward=0.5, next_state=(37, 57, 222, 221, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 40082}, q_values=[(146, 0.0), (147, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(227, 241, 215, 183, 0, 0), action=179, reward=0.0, next_state=(227, 241, 215, 183, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(178, 0.0), (179, 0.0), (180, 0.0), (181, 0.0), (183, 0.0)]), StepLog(t=1, state=(227, 241, 215, 183, 0, 1), action=167, reward=0.5, next_state=(79, 103, 237, 120, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 45991}, q_values=[(165, 0.0), (166, 0.0), (167, 0.0), (197, 0.0), (198, 0.0), (199, 0.0), (245, 0.0), (246, 0.0), (247, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(194, 140, 203, 172, 0, 0), action=130, reward=0.0, next_state=(194, 140, 203, 172, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(130, 0.0), (131, 0.0), (136, 0.0), (137, 0.0), (142, 0.0), (143, 0.0)]), StepLog(t=1, state=(194, 140, 203, 172, 0, 1), action=137, reward=0.5, next_state=(19, 5, 172, 58, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 33417}, q_values=[(136, 0.0), (137, 0.0), (138, 0.0), (140, 0.0), (160, 0.0), (161, 0.0), (162, 0.0), (164, 0.0), (172, 0.0), (173, 0.0), (174, 0.0), (184, 0.0), (185, 0.0), (186, 0.0), (188, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(171, 158, 194, 254, 0, 0), action=226, reward=0.0, next_state=(171, 158, 194, 254, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(226, 0.0), (227, 0.0), (232, 0.0), (233, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(171, 158, 194, 254, 0, 1), action=209, reward=0.5, next_state=(163, 197, 233, 42, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 58065}, q_values=[(208, 0.0), (209, 0.0), (210, 0.0), (214, 0.0), (215, 0.0), (220, 0.0), (221, 0.0), (222, 0.0), (224, 0.0), (225, 0.0), (226, 0.0), (230, 0.0), (231, 0.0), (236, 0.0), (237, 0.0), (238, 0.0), (248, 0.0), (249, 0.0), (250, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=2, state=(163, 197, 233, 42, 0, 0), action=169, reward=0.0, next_state=(163, 197, 233, 42, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(169, 0.0), (170, 0.0), (171, 0.0), (201, 0.0), (202, 0.0), (203, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(229, 78, 145, 230, 0, 0), action=244, reward=0.0, next_state=(229, 78, 145, 230, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(241, 0.0), (244, 0.0), (245, 0.0), (247, 0.0)]), StepLog(t=1, state=(229, 78, 145, 230, 0, 1), action=None, reward=0.0, next_state=(229, 78, 145, 230, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(227, 1, 254, 50, 0, 0), action=155, reward=0.0, next_state=(227, 1, 254, 50, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(154, 0.0), (155, 0.0), (156, 0.0), (157, 0.0), (250, 0.0), (251, 0.0), (252, 0.0), (253, 0.0)]), StepLog(t=1, state=(227, 1, 254, 50, 0, 1), action=None, reward=0.0, next_state=(227, 1, 254, 50, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(250, 70, 202, 170, 0, 0), action=178, reward=0.0, next_state=(250, 70, 202, 170, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(168, 0.0), (169, 0.0), (170, 0.0), (174, 0.0), (175, 0.0), (176, 0.0), (177, 0.0), (178, 0.0), (182, 0.0), (183, 0.0), (186, 0.0), (187, 0.0)]), StepLog(t=1, state=(250, 70, 202, 170, 0, 1), action=None, reward=0.0, next_state=(250, 70, 202, 170, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(201, 109, 179, 117, 0, 0), action=251, reward=0.0, next_state=(201, 109, 179, 117, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(249, 0.0), (250, 0.0), (251, 0.0)]), StepLog(t=1, state=(201, 109, 179, 117, 0, 1), action=85, reward=0.5, next_state=(171, 246, 54, 131, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 64341}, q_values=[(84, 0.0), (85, 0.0), (87, 0.0), (88, 0.0), (89, 0.0), (91, 0.0), (93, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(134, 142, 250, 16, 0, 0), action=251, reward=0.0, next_state=(134, 142, 250, 16, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(250, 0.0), (251, 0.0), (252, 0.0), (253, 0.0), (254, 0.0)]), StepLog(t=1, state=(134, 142, 250, 16, 0, 1), action=None, reward=0.0, next_state=(134, 142, 250, 16, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(216, 109, 164, 142, 0, 0), action=248, reward=0.0, next_state=(216, 109, 164, 142, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(248, 0.0), (252, 0.0), (253, 0.0), (254, 0.0)]), StepLog(t=1, state=(216, 109, 164, 142, 0, 1), action=None, reward=0.0, next_state=(216, 109, 164, 142, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(206, 31, 154, 254, 0, 0), action=210, reward=0.0, next_state=(206, 31, 154, 254, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(202, 0.0), (203, 0.0), (204, 0.0), (205, 0.0), (206, 0.0), (210, 0.0), (211, 0.0), (212, 0.0), (213, 0.0), (214, 0.0)]), StepLog(t=1, state=(206, 31, 154, 254, 0, 1), action=None, reward=0.0, next_state=(206, 31, 154, 254, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(88, 30, 78, 78, 0, 0), action=86, reward=0.0, next_state=(88, 30, 78, 78, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(76, 0.0), (78, 0.0), (79, 0.0), (84, 0.0), (86, 0.0), (87, 0.0)]), StepLog(t=1, state=(88, 30, 78, 78, 0, 1), action=None, reward=0.0, next_state=(88, 30, 78, 78, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(160, 25, 241, 161, 0, 0), action=208, reward=0.0, next_state=(160, 25, 241, 161, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(176, 0.0), (177, 0.0), (208, 0.0), (209, 0.0)]), StepLog(t=1, state=(160, 25, 241, 161, 0, 1), action=None, reward=0.0, next_state=(160, 25, 241, 161, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(143, 38, 246, 37, 0, 0), action=244, reward=0.0, next_state=(143, 38, 246, 37, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(244, 0.0), (245, 0.0), (248, 0.0), (249, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(143, 38, 246, 37, 0, 1), action=34, reward=0.5, next_state=(69, 232, 44, 181, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 62498}, q_values=[(34, 0.0), (35, 0.0), (46, 0.0), (47, 0.0), (54, 0.0), (55, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(227, 246, 184, 109, 0, 0), action=186, reward=0.0, next_state=(227, 246, 184, 109, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(186, 0.0), (187, 0.0), (218, 0.0), (219, 0.0)]), StepLog(t=1, state=(227, 246, 184, 109, 0, 1), action=None, reward=0.0, next_state=(227, 246, 184, 109, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(166, 148, 209, 115, 0, 0), action=247, reward=0.0, next_state=(166, 148, 209, 115, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(246, 0.0), (247, 0.0)]), StepLog(t=1, state=(166, 148, 209, 115, 0, 1), action=None, reward=0.0, next_state=(166, 148, 209, 115, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(129, 172, 131, 82, 0, 0), action=131, reward=0.0, next_state=(129, 172, 131, 82, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(129, 0.0), (130, 0.0), (131, 0.0)]), StepLog(t=1, state=(129, 172, 131, 82, 0, 1), action=None, reward=0.0, next_state=(129, 172, 131, 82, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(79, 179, 66, 156, 0, 0), action=74, reward=0.0, next_state=(79, 179, 66, 156, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(74, 0.0), (75, 0.0), (76, 0.0), (77, 0.0)]), StepLog(t=1, state=(79, 179, 66, 156, 0, 1), action=174, reward=0.5, next_state=(92, 149, 64, 223, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 19118}, q_values=[(158, 0.0), (159, 0.0), (174, 0.0), (175, 0.0)]), StepLog(t=2, state=(92, 149, 64, 223, 0, 0), action=88, reward=0.0, next_state=(92, 149, 64, 223, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(88, 0.0), (92, 0.0), (93, 0.0), (94, 0.0)]), StepLog(t=3, state=(92, 149, 64, 223, 0, 1), action=151, reward=0.5, next_state=(46, 177, 91, 234, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 22679}, q_values=[(149, 0.0), (150, 0.0), (151, 0.0), (153, 0.0), (154, 0.0), (155, 0.0), (197, 0.0), (198, 0.0), (199, 0.0), (201, 0.0), (202, 0.0), (203, 0.0), (245, 0.0), (246, 0.0), (247, 0.0), (249, 0.0), (250, 0.0), (251, 0.0)])], return_=1.0),
#  PathLog(steps=[StepLog(t=0, state=(234, 47, 133, 56, 0, 0), action=238, reward=0.0, next_state=(234, 47, 133, 56, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(238, 0.0), (239, 0.0)]), StepLog(t=1, state=(234, 47, 133, 56, 0, 1), action=46, reward=0.5, next_state=(93, 220, 250, 204, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 60974}, q_values=[(46, 0.0), (47, 0.0), (54, 0.0), (55, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(84, 47, 115, 88, 0, 0), action=87, reward=0.0, next_state=(84, 47, 115, 88, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(86, 0.0), (87, 0.0), (102, 0.0), (103, 0.0)]), StepLog(t=1, state=(84, 47, 115, 88, 0, 1), action=None, reward=0.0, next_state=(84, 47, 115, 88, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(117, 236, 122, 171, 0, 0), action=78, reward=0.0, next_state=(117, 236, 122, 171, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(78, 0.0), (79, 0.0), (126, 0.0), (127, 0.0)]), StepLog(t=1, state=(117, 236, 122, 171, 0, 1), action=166, reward=0.5, next_state=(76, 157, 164, 11, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 20134}, q_values=[(166, 0.0), (167, 0.0), (190, 0.0), (191, 0.0), (198, 0.0), (199, 0.0), (222, 0.0), (223, 0.0), (238, 0.0), (239, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(63, 222, 61, 27, 0, 0), action=59, reward=0.0, next_state=(63, 222, 61, 27, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(33, 0.0), (34, 0.0), (35, 0.0), (45, 0.0), (46, 0.0), (47, 0.0), (57, 0.0), (58, 0.0), (59, 0.0)]), StepLog(t=1, state=(63, 222, 61, 27, 0, 1), action=None, reward=0.0, next_state=(63, 222, 61, 27, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(222, 7, 195, 198, 0, 0), action=156, reward=0.0, next_state=(222, 7, 195, 198, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(154, 0.0), (155, 0.0), (156, 0.0), (157, 0.0)]), StepLog(t=1, state=(222, 7, 195, 198, 0, 1), action=None, reward=0.0, next_state=(222, 7, 195, 198, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(243, 185, 141, 63, 0, 0), action=253, reward=0.0, next_state=(243, 185, 141, 63, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(253, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(243, 185, 141, 63, 0, 1), action=None, reward=0.0, next_state=(243, 185, 141, 63, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(196, 249, 228, 167, 0, 0), action=133, reward=0.0, next_state=(196, 249, 228, 167, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(132, 0.0), (133, 0.0), (134, 0.0), (160, 0.0), (161, 0.0), (162, 0.0), (164, 0.0), (172, 0.0), (173, 0.0), (174, 0.0), (180, 0.0), (181, 0.0), (182, 0.0)]), StepLog(t=1, state=(196, 249, 228, 167, 0, 1), action=191, reward=0.5, next_state=(127, 11, 23, 32, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 34239}, q_values=[(189, 0.0), (190, 0.0), (191, 0.0), (221, 0.0), (222, 0.0), (223, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(121, 46, 79, 146, 0, 0), action=119, reward=0.0, next_state=(121, 46, 79, 146, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(109, 0.0), (110, 0.0), (111, 0.0), (117, 0.0), (118, 0.0), (119, 0.0)]), StepLog(t=1, state=(121, 46, 79, 146, 0, 1), action=None, reward=0.0, next_state=(121, 46, 79, 146, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(215, 2, 253, 94, 0, 0), action=165, reward=0.0, next_state=(215, 2, 253, 94, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(149, 0.0), (150, 0.0), (151, 0.0), (153, 0.0), (154, 0.0), (155, 0.0), (165, 0.0), (166, 0.0), (167, 0.0), (169, 0.0), (170, 0.0), (171, 0.0)]), StepLog(t=1, state=(215, 2, 253, 94, 0, 1), action=None, reward=0.0, next_state=(215, 2, 253, 94, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(71, 215, 101, 159, 0, 0), action=71, reward=0.0, next_state=(71, 215, 101, 159, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(69, 0.0), (70, 0.0), (71, 0.0), (97, 0.0), (98, 0.0), (99, 0.0), (109, 0.0), (110, 0.0), (111, 0.0), (117, 0.0), (118, 0.0), (119, 0.0)]), StepLog(t=1, state=(71, 215, 101, 159, 0, 1), action=197, reward=0.5, next_state=(138, 143, 209, 184, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 18373}, q_values=[(148, 0.0), (149, 0.0), (151, 0.0), (152, 0.0), (153, 0.0), (155, 0.0), (158, 0.0), (159, 0.0), (196, 0.0), (197, 0.0), (199, 0.0), (200, 0.0), (201, 0.0), (203, 0.0), (206, 0.0), (207, 0.0), (244, 0.0), (245, 0.0), (247, 0.0), (248, 0.0), (249, 0.0), (251, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=2, state=(138, 143, 209, 184, 0, 0), action=218, reward=0.0, next_state=(138, 143, 209, 184, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(218, 0.0), (219, 0.0)]), StepLog(t=3, state=(138, 143, 209, 184, 0, 1), action=174, reward=0.5, next_state=(93, 181, 156, 77, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 55982}, q_values=[(174, 0.0), (175, 0.0), (182, 0.0), (183, 0.0)])], return_=1.0),
#  PathLog(steps=[StepLog(t=0, state=(65, 127, 88, 102, 0, 0), action=88, reward=0.0, next_state=(65, 127, 88, 102, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(88, 0.0), (89, 0.0)]), StepLog(t=1, state=(65, 127, 88, 102, 0, 1), action=88, reward=0.5, next_state=(176, 176, 57, 193, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 22616}, q_values=[(84, 0.0), (85, 0.0), (88, 0.0), (89, 0.0), (94, 0.0), (95, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(219, 161, 238, 104, 0, 0), action=178, reward=0.0, next_state=(219, 161, 238, 104, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(170, 0.0), (171, 0.0), (172, 0.0), (173, 0.0), (178, 0.0), (179, 0.0), (180, 0.0), (181, 0.0)]), StepLog(t=1, state=(219, 161, 238, 104, 0, 1), action=None, reward=0.0, next_state=(219, 161, 238, 104, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(65, 41, 115, 153, 0, 0), action=114, reward=0.0, next_state=(65, 41, 115, 153, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(113, 0.0), (114, 0.0), (115, 0.0)]), StepLog(t=1, state=(65, 41, 115, 153, 0, 1), action=None, reward=0.0, next_state=(65, 41, 115, 153, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(238, 32, 133, 121, 0, 0), action=235, reward=0.0, next_state=(238, 32, 133, 121, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(230, 0.0), (231, 0.0), (234, 0.0), (235, 0.0)]), StepLog(t=1, state=(238, 32, 133, 121, 0, 1), action=None, reward=0.0, next_state=(238, 32, 133, 121, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(86, 39, 89, 219, 0, 0), action=79, reward=0.0, next_state=(86, 39, 89, 219, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(78, 0.0), (79, 0.0), (126, 0.0), (127, 0.0)]), StepLog(t=1, state=(86, 39, 89, 219, 0, 1), action=None, reward=0.0, next_state=(86, 39, 89, 219, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(204, 33, 166, 94, 0, 0), action=230, reward=0.0, next_state=(204, 33, 166, 94, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(228, 0.0), (230, 0.0), (231, 0.0), (232, 0.0), (234, 0.0), (235, 0.0)]), StepLog(t=1, state=(204, 33, 166, 94, 0, 1), action=None, reward=0.0, next_state=(204, 33, 166, 94, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(248, 192, 188, 83, 0, 0), action=164, reward=0.0, next_state=(248, 192, 188, 83, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(160, 0.0), (164, 0.0), (165, 0.0), (166, 0.0), (184, 0.0), (188, 0.0), (189, 0.0), (190, 0.0), (192, 0.0), (196, 0.0), (197, 0.0), (198, 0.0), (216, 0.0), (220, 0.0), (221, 0.0), (222, 0.0), (240, 0.0), (244, 0.0), (245, 0.0), (246, 0.0)]), StepLog(t=1, state=(248, 192, 188, 83, 0, 1), action=None, reward=0.0, next_state=(248, 192, 188, 83, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(242, 187, 186, 151, 0, 0), action=163, reward=0.0, next_state=(242, 187, 186, 151, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(162, 0.0), (163, 0.0), (168, 0.0), (169, 0.0), (170, 0.0), (174, 0.0), (175, 0.0), (194, 0.0), (195, 0.0), (200, 0.0), (201, 0.0), (202, 0.0), (206, 0.0), (207, 0.0), (242, 0.0), (243, 0.0), (248, 0.0), (249, 0.0), (250, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(242, 187, 186, 151, 0, 1), action=155, reward=0.5, next_state=(55, 71, 73, 197, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 41883}, q_values=[(154, 0.0), (155, 0.0), (156, 0.0), (157, 0.0), (159, 0.0), (170, 0.0), (171, 0.0), (172, 0.0), (173, 0.0), (175, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(177, 82, 190, 207, 0, 0), action=239, reward=0.0, next_state=(177, 82, 190, 207, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(142, 0.0), (143, 0.0), (190, 0.0), (191, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(177, 82, 190, 207, 0, 1), action=None, reward=0.0, next_state=(177, 82, 190, 207, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(214, 226, 241, 246, 0, 0), action=150, reward=0.0, next_state=(214, 226, 241, 246, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(150, 0.0), (151, 0.0), (166, 0.0), (167, 0.0)]), StepLog(t=1, state=(214, 226, 241, 246, 0, 1), action=147, reward=0.5, next_state=(39, 45, 81, 72, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 38547}, q_values=[(146, 0.0), (147, 0.0), (148, 0.0), (149, 0.0), (150, 0.0), (242, 0.0), (243, 0.0), (244, 0.0), (245, 0.0), (246, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(83, 166, 104, 213, 0, 0), action=122, reward=0.0, next_state=(83, 166, 104, 213, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(122, 0.0), (123, 0.0)]), StepLog(t=1, state=(83, 166, 104, 213, 0, 1), action=230, reward=0.5, next_state=(204, 245, 217, 179, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 31462}, q_values=[(230, 0.0), (231, 0.0), (242, 0.0), (243, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=2, state=(204, 245, 217, 179, 0, 0), action=140, reward=0.0, next_state=(204, 245, 217, 179, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(140, 0.0), (141, 0.0), (148, 0.0), (149, 0.0)]), StepLog(t=3, state=(204, 245, 217, 179, 0, 1), action=167, reward=0.5, next_state=(79, 25, 234, 104, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 36007}, q_values=[(165, 0.0), (166, 0.0), (167, 0.0), (197, 0.0), (198, 0.0), (199, 0.0), (245, 0.0), (246, 0.0), (247, 0.0)])], return_=1.0),
#  PathLog(steps=[StepLog(t=0, state=(172, 81, 162, 173, 0, 0), action=142, reward=0.0, next_state=(172, 81, 162, 173, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(140, 0.0), (142, 0.0), (143, 0.0), (236, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(172, 81, 162, 173, 0, 1), action=None, reward=0.0, next_state=(172, 81, 162, 173, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(151, 208, 206, 36, 0, 0), action=217, reward=0.0, next_state=(151, 208, 206, 36, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(212, 0.0), (213, 0.0), (216, 0.0), (217, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(151, 208, 206, 36, 0, 1), action=None, reward=0.0, next_state=(151, 208, 206, 36, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(174, 187, 198, 32, 0, 0), action=232, reward=0.0, next_state=(174, 187, 198, 32, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(228, 0.0), (229, 0.0), (230, 0.0), (232, 0.0), (233, 0.0), (234, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(174, 187, 198, 32, 0, 1), action=None, reward=0.0, next_state=(174, 187, 198, 32, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(86, 23, 71, 191, 0, 0), action=81, reward=0.0, next_state=(86, 23, 71, 191, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(68, 0.0), (69, 0.0), (80, 0.0), (81, 0.0), (86, 0.0), (87, 0.0), (92, 0.0), (93, 0.0)]), StepLog(t=1, state=(86, 23, 71, 191, 0, 1), action=None, reward=0.0, next_state=(86, 23, 71, 191, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(214, 18, 230, 178, 0, 0), action=166, reward=0.0, next_state=(214, 18, 230, 178, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(164, 0.0), (165, 0.0), (166, 0.0), (176, 0.0), (177, 0.0), (178, 0.0), (182, 0.0), (183, 0.0), (188, 0.0), (189, 0.0), (190, 0.0)]), StepLog(t=1, state=(214, 18, 230, 178, 0, 1), action=None, reward=0.0, next_state=(214, 18, 230, 178, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(169, 50, 140, 158, 0, 0), action=188, reward=0.0, next_state=(169, 50, 140, 158, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(140, 0.0), (141, 0.0), (164, 0.0), (165, 0.0), (188, 0.0), (189, 0.0)]), StepLog(t=1, state=(169, 50, 140, 158, 0, 1), action=None, reward=0.0, next_state=(169, 50, 140, 158, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(255, 166, 199, 235, 0, 0), action=181, reward=0.0, next_state=(255, 166, 199, 235, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(180, 0.0), (181, 0.0), (183, 0.0), (184, 0.0), (185, 0.0), (187, 0.0), (190, 0.0), (191, 0.0)]), StepLog(t=1, state=(255, 166, 199, 235, 0, 1), action=202, reward=0.5, next_state=(149, 107, 170, 101, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 46538}, q_values=[(170, 0.0), (171, 0.0), (172, 0.0), (173, 0.0), (202, 0.0), (203, 0.0), (204, 0.0), (205, 0.0)]), StepLog(t=2, state=(149, 107, 170, 101, 0, 0), action=190, reward=0.0, next_state=(149, 107, 170, 101, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(190, 0.0), (191, 0.0)]), StepLog(t=3, state=(149, 107, 170, 101, 0, 1), action=79, reward=0.5, next_state=(159, 124, 23, 217, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 48719}, q_values=[(77, 0.0), (78, 0.0), (79, 0.0)])], return_=1.0),
#  PathLog(steps=[StepLog(t=0, state=(191, 211, 216, 202, 0, 0), action=214, reward=0.0, next_state=(191, 211, 216, 202, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(214, 0.0), (215, 0.0), (230, 0.0), (231, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(191, 211, 216, 202, 0, 1), action=146, reward=0.5, next_state=(37, 173, 181, 185, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 54930}, q_values=[(146, 0.0), (147, 0.0), (152, 0.0), (153, 0.0), (158, 0.0), (159, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(106, 201, 98, 66, 0, 0), action=67, reward=0.0, next_state=(106, 201, 98, 66, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(66, 0.0), (67, 0.0), (72, 0.0), (73, 0.0), (74, 0.0), (78, 0.0), (79, 0.0)]), StepLog(t=1, state=(106, 201, 98, 66, 0, 1), action=None, reward=0.0, next_state=(106, 201, 98, 66, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(89, 121, 126, 6, 0, 0), action=103, reward=0.0, next_state=(89, 121, 126, 6, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(86, 0.0), (87, 0.0), (102, 0.0), (103, 0.0), (126, 0.0), (127, 0.0)]), StepLog(t=1, state=(89, 121, 126, 6, 0, 1), action=None, reward=0.0, next_state=(89, 121, 126, 6, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(193, 203, 253, 131, 0, 0), action=189, reward=0.0, next_state=(193, 203, 253, 131, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(185, 0.0), (188, 0.0), (189, 0.0), (191, 0.0)]), StepLog(t=1, state=(193, 203, 253, 131, 0, 1), action=207, reward=0.5, next_state=(159, 123, 75, 192, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 48591}, q_values=[(194, 0.0), (195, 0.0), (200, 0.0), (201, 0.0), (203, 0.0), (206, 0.0), (207, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(205, 218, 158, 239, 0, 0), action=202, reward=0.0, next_state=(205, 218, 158, 239, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(202, 0.0), (203, 0.0), (210, 0.0), (211, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(205, 218, 158, 239, 0, 1), action=170, reward=0.5, next_state=(85, 149, 177, 20, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 51882}, q_values=[(170, 0.0), (171, 0.0), (172, 0.0), (173, 0.0), (178, 0.0), (179, 0.0), (180, 0.0), (181, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(172, 211, 179, 161, 0, 0), action=158, reward=0.0, next_state=(172, 211, 179, 161, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(158, 0.0), (159, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(172, 211, 179, 161, 0, 1), action=243, reward=0.5, next_state=(231, 61, 80, 117, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 40691}, q_values=[(241, 0.0), (242, 0.0), (243, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(137, 149, 145, 231, 0, 0), action=153, reward=0.0, next_state=(137, 149, 145, 231, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(145, 0.0), (152, 0.0), (153, 0.0), (155, 0.0), (157, 0.0)]), StepLog(t=1, state=(137, 149, 145, 231, 0, 1), action=231, reward=0.5, next_state=(207, 51, 222, 121, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 39399}, q_values=[(229, 0.0), (230, 0.0), (231, 0.0), (241, 0.0), (242, 0.0), (243, 0.0), (253, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=2, state=(207, 51, 222, 121, 0, 0), action=136, reward=0.0, next_state=(207, 51, 222, 121, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(136, 0.0), (137, 0.0), (142, 0.0), (143, 0.0), (144, 0.0), (145, 0.0), (150, 0.0), (151, 0.0), (156, 0.0), (157, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(55, 237, 49, 41, 0, 0), action=37, reward=0.0, next_state=(55, 237, 49, 41, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(37, 0.0), (38, 0.0), (39, 0.0)]), StepLog(t=1, state=(55, 237, 49, 41, 0, 1), action=None, reward=0.0, next_state=(55, 237, 49, 41, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(161, 207, 229, 168, 0, 0), action=165, reward=0.0, next_state=(161, 207, 229, 168, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(161, 0.0), (164, 0.0), (165, 0.0), (167, 0.0), (193, 0.0), (196, 0.0), (197, 0.0), (199, 0.0)]), StepLog(t=1, state=(161, 207, 229, 168, 0, 1), action=206, reward=0.5, next_state=(157, 75, 51, 109, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 42446}, q_values=[(206, 0.0), (207, 0.0), (230, 0.0), (231, 0.0), (254, 0.0), (255, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(191, 233, 219, 11, 0, 0), action=229, reward=0.0, next_state=(191, 233, 219, 11, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(210, 0.0), (211, 0.0), (212, 0.0), (213, 0.0), (215, 0.0), (226, 0.0), (227, 0.0), (228, 0.0), (229, 0.0), (231, 0.0), (250, 0.0), (251, 0.0), (252, 0.0), (253, 0.0), (255, 0.0)]), StepLog(t=1, state=(191, 233, 219, 11, 0, 1), action=None, reward=0.0, next_state=(191, 233, 219, 11, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(144, 185, 167, 17, 0, 0), action=182, reward=0.0, next_state=(144, 185, 167, 17, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(182, 0.0), (183, 0.0)]), StepLog(t=1, state=(144, 185, 167, 17, 0, 1), action=None, reward=0.0, next_state=(144, 185, 167, 17, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(17, 226, 26, 51, 0, 0), action=26, reward=0.0, next_state=(17, 226, 26, 51, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(26, 0.0), (27, 0.0)]), StepLog(t=1, state=(17, 226, 26, 51, 0, 1), action=None, reward=0.0, next_state=(17, 226, 26, 51, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(245, 214, 149, 97, 0, 0), action=221, reward=0.0, next_state=(245, 214, 149, 97, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(208, 0.0), (209, 0.0), (211, 0.0), (213, 0.0), (220, 0.0), (221, 0.0), (223, 0.0), (224, 0.0), (225, 0.0), (227, 0.0), (229, 0.0), (236, 0.0), (237, 0.0), (239, 0.0), (244, 0.0), (245, 0.0), (247, 0.0)]), StepLog(t=1, state=(245, 214, 149, 97, 0, 1), action=None, reward=0.0, next_state=(245, 214, 149, 97, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(121, 209, 113, 141, 0, 0), action=73, reward=0.0, next_state=(121, 209, 113, 141, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(65, 0.0), (72, 0.0), (73, 0.0), (75, 0.0), (77, 0.0), (113, 0.0), (120, 0.0), (121, 0.0), (123, 0.0), (125, 0.0)]), StepLog(t=1, state=(121, 209, 113, 141, 0, 1), action=221, reward=0.5, next_state=(186, 147, 143, 232, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 18909}, q_values=[(217, 0.0), (220, 0.0), (221, 0.0), (223, 0.0)]), StepLog(t=2, state=(186, 147, 143, 232, 0, 0), action=170, reward=0.0, next_state=(186, 147, 143, 232, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(170, 0.0), (171, 0.0), (172, 0.0), (173, 0.0), (178, 0.0), (179, 0.0), (180, 0.0), (181, 0.0)]), StepLog(t=3, state=(186, 147, 143, 232, 0, 1), action=250, reward=0.5, next_state=(245, 85, 149, 88, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 43770}, q_values=[(250, 0.0), (251, 0.0)]), StepLog(t=4, state=(245, 85, 149, 88, 0, 0), action=209, reward=0.0, next_state=(245, 85, 149, 88, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(208, 0.0), (209, 0.0), (211, 0.0), (213, 0.0), (220, 0.0), (221, 0.0), (223, 0.0), (224, 0.0), (225, 0.0), (227, 0.0), (229, 0.0), (236, 0.0), (237, 0.0), (239, 0.0), (244, 0.0), (245, 0.0), (247, 0.0)]), StepLog(t=5, state=(245, 85, 149, 88, 0, 1), action=76, reward=0.5, next_state=(153, 162, 132, 46, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 53580}, q_values=[(76, 0.0), (77, 0.0), (124, 0.0), (125, 0.0)]), StepLog(t=6, state=(153, 162, 132, 46, 0, 0), action=156, reward=0.0, next_state=(153, 162, 132, 46, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(156, 0.0), (157, 0.0)])], return_=1.5),
#  PathLog(steps=[StepLog(t=0, state=(139, 75, 245, 40, 0, 0), action=254, reward=0.0, next_state=(139, 75, 245, 40, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(253, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(139, 75, 245, 40, 0, 1), action=None, reward=0.0, next_state=(139, 75, 245, 40, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(157, 180, 249, 127, 0, 0), action=215, reward=0.0, next_state=(157, 180, 249, 127, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(209, 0.0), (212, 0.0), (213, 0.0), (215, 0.0), (225, 0.0), (228, 0.0), (229, 0.0), (231, 0.0), (249, 0.0), (252, 0.0), (253, 0.0), (255, 0.0)]), StepLog(t=1, state=(157, 180, 249, 127, 0, 1), action=None, reward=0.0, next_state=(157, 180, 249, 127, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(83, 251, 74, 94, 0, 0), action=83, reward=0.0, next_state=(83, 251, 74, 94, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(82, 0.0), (83, 0.0), (88, 0.0), (89, 0.0), (94, 0.0), (95, 0.0)]), StepLog(t=1, state=(83, 251, 74, 94, 0, 1), action=None, reward=0.0, next_state=(83, 251, 74, 94, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(86, 248, 117, 184, 0, 0), action=98, reward=0.0, next_state=(86, 248, 117, 184, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(82, 0.0), (83, 0.0), (94, 0.0), (95, 0.0), (98, 0.0), (99, 0.0), (110, 0.0), (111, 0.0), (118, 0.0), (119, 0.0)]), StepLog(t=1, state=(86, 248, 117, 184, 0, 1), action=188, reward=0.5, next_state=(120, 197, 180, 93, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 25276}, q_values=[(160, 0.0), (161, 0.0), (162, 0.0), (164, 0.0), (168, 0.0), (184, 0.0), (185, 0.0), (186, 0.0), (188, 0.0), (192, 0.0), (193, 0.0), (194, 0.0), (196, 0.0), (200, 0.0), (216, 0.0), (217, 0.0), (218, 0.0), (220, 0.0), (240, 0.0), (241, 0.0), (242, 0.0), (244, 0.0), (248, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(176, 65, 228, 94, 0, 0), action=176, reward=0.0, next_state=(176, 65, 228, 94, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(176, 0.0), (180, 0.0), (181, 0.0), (182, 0.0), (208, 0.0), (212, 0.0), (213, 0.0), (214, 0.0)]), StepLog(t=1, state=(176, 65, 228, 94, 0, 1), action=94, reward=0.5, next_state=(189, 96, 33, 37, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 45150}, q_values=[(94, 0.0), (95, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(177, 179, 231, 235, 0, 0), action=183, reward=0.0, next_state=(177, 179, 231, 235, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(181, 0.0), (182, 0.0), (183, 0.0), (213, 0.0), (214, 0.0), (215, 0.0)]), StepLog(t=1, state=(177, 179, 231, 235, 0, 1), action=179, reward=0.5, next_state=(103, 111, 40, 28, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 47027}, q_values=[(178, 0.0), (179, 0.0), (184, 0.0), (185, 0.0), (187, 0.0), (190, 0.0), (191, 0.0), (210, 0.0), (211, 0.0), (216, 0.0), (217, 0.0), (219, 0.0), (222, 0.0), (223, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(206, 74, 201, 66, 0, 0), action=134, reward=0.0, next_state=(206, 74, 201, 66, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(134, 0.0), (135, 0.0), (158, 0.0), (159, 0.0), (174, 0.0), (175, 0.0), (206, 0.0), (207, 0.0)]), StepLog(t=1, state=(206, 74, 201, 66, 0, 1), action=67, reward=0.5, next_state=(135, 12, 163, 72, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 34371}, q_values=[(66, 0.0), (67, 0.0), (72, 0.0), (73, 0.0), (74, 0.0), (78, 0.0), (79, 0.0)]), StepLog(t=2, state=(135, 12, 163, 72, 0, 0), action=162, reward=0.0, next_state=(135, 12, 163, 72, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(162, 0.0), (163, 0.0), (164, 0.0), (165, 0.0), (167, 0.0)])], return_=0.5),
# ...
#  PathLog(steps=[StepLog(t=0, state=(84, 166, 119, 203, 0, 0), action=82, reward=0.0, next_state=(84, 166, 119, 203, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(82, 0.0), (83, 0.0), (94, 0.0), (95, 0.0), (98, 0.0), (99, 0.0), (110, 0.0), (111, 0.0), (118, 0.0), (119, 0.0)]), StepLog(t=1, state=(84, 166, 119, 203, 0, 1), action=234, reward=0.5, next_state=(212, 165, 141, 199, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 21226}, q_values=[(234, 0.0), (235, 0.0), (236, 0.0), (237, 0.0)]), StepLog(t=2, state=(212, 165, 141, 199, 0, 0), action=212, reward=0.0, next_state=(212, 165, 141, 199, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(212, 0.0), (213, 0.0), (216, 0.0), (217, 0.0)]), StepLog(t=3, state=(212, 165, 141, 199, 0, 1), action=199, reward=0.5, next_state=(143, 169, 227, 217, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 54471}, q_values=[(197, 0.0), (198, 0.0), (199, 0.0), (225, 0.0), (226, 0.0), (227, 0.0), (237, 0.0), (238, 0.0), (239, 0.0), (245, 0.0), (246, 0.0), (247, 0.0)]), StepLog(t=4, state=(143, 169, 227, 217, 0, 0), action=235, reward=0.0, next_state=(143, 169, 227, 217, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(234, 0.0), (235, 0.0), (236, 0.0), (237, 0.0), (239, 0.0)]), StepLog(t=5, state=(143, 169, 227, 217, 0, 1), action=233, reward=0.5, next_state=(211, 215, 100, 142, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 60393}, q_values=[(232, 0.0), (233, 0.0), (235, 0.0), (237, 0.0), (240, 0.0), (241, 0.0), (243, 0.0), (245, 0.0), (249, 0.0)])], return_=1.5),
#  PathLog(steps=[StepLog(t=0, state=(206, 135, 164, 204, 0, 0), action=228, reward=0.0, next_state=(206, 135, 164, 204, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(228, 0.0), (230, 0.0), (231, 0.0), (232, 0.0), (234, 0.0), (235, 0.0)]), StepLog(t=1, state=(206, 135, 164, 204, 0, 1), action=198, reward=0.5, next_state=(141, 201, 119, 244, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 58566}, q_values=[(198, 0.0), (199, 0.0), (202, 0.0), (203, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(239, 68, 188, 156, 0, 0), action=179, reward=0.0, next_state=(239, 68, 188, 156, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(170, 0.0), (171, 0.0), (178, 0.0), (179, 0.0), (190, 0.0), (191, 0.0), (202, 0.0), (203, 0.0), (210, 0.0), (211, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(239, 68, 188, 156, 0, 1), action=None, reward=0.0, next_state=(239, 68, 188, 156, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(84, 222, 101, 49, 0, 0), action=100, reward=0.0, next_state=(84, 222, 101, 49, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(100, 0.0), (101, 0.0), (112, 0.0), (113, 0.0), (124, 0.0), (125, 0.0)]), StepLog(t=1, state=(84, 222, 101, 49, 0, 1), action=None, reward=0.0, next_state=(84, 222, 101, 49, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(231, 171, 211, 36, 0, 0), action=179, reward=0.0, next_state=(231, 171, 211, 36, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(178, 0.0), (179, 0.0), (180, 0.0), (181, 0.0), (183, 0.0)]), StepLog(t=1, state=(231, 171, 211, 36, 0, 1), action=None, reward=0.0, next_state=(231, 171, 211, 36, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(99, 93, 89, 212, 0, 0), action=121, reward=0.0, next_state=(99, 93, 89, 212, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(121, 0.0), (122, 0.0), (123, 0.0)]), StepLog(t=1, state=(99, 93, 89, 212, 0, 1), action=None, reward=0.0, next_state=(99, 93, 89, 212, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(156, 70, 239, 220, 0, 0), action=234, reward=0.0, next_state=(156, 70, 239, 220, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(234, 0.0), (235, 0.0), (242, 0.0), (243, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(156, 70, 239, 220, 0, 1), action=None, reward=0.0, next_state=(156, 70, 239, 220, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(136, 75, 206, 180, 0, 0), action=223, reward=0.0, next_state=(136, 75, 206, 180, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(140, 0.0), (142, 0.0), (143, 0.0), (196, 0.0), (198, 0.0), (199, 0.0), (220, 0.0), (222, 0.0), (223, 0.0), (236, 0.0), (238, 0.0), (239, 0.0)]), StepLog(t=1, state=(136, 75, 206, 180, 0, 1), action=None, reward=0.0, next_state=(136, 75, 206, 180, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(74, 42, 84, 212, 0, 0), action=95, reward=0.0, next_state=(74, 42, 84, 212, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(92, 0.0), (94, 0.0), (95, 0.0)]), StepLog(t=1, state=(74, 42, 84, 212, 0, 1), action=None, reward=0.0, next_state=(74, 42, 84, 212, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(196, 132, 226, 134, 0, 0), action=164, reward=0.0, next_state=(196, 132, 226, 134, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(164, 0.0), (166, 0.0), (167, 0.0)]), StepLog(t=1, state=(196, 132, 226, 134, 0, 1), action=140, reward=0.5, next_state=(25, 73, 46, 151, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 42124}, q_values=[(128, 0.0), (130, 0.0), (131, 0.0), (140, 0.0), (142, 0.0), (143, 0.0), (148, 0.0), (150, 0.0), (151, 0.0), (164, 0.0), (166, 0.0), (167, 0.0), (196, 0.0), (198, 0.0), (199, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(168, 118, 146, 205, 0, 0), action=187, reward=0.0, next_state=(168, 118, 146, 205, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(184, 0.0), (186, 0.0), (187, 0.0)]), StepLog(t=1, state=(168, 118, 146, 205, 0, 1), action=None, reward=0.0, next_state=(168, 118, 146, 205, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(97, 181, 113, 151, 0, 0), action=81, reward=0.0, next_state=(97, 181, 113, 151, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(65, 0.0), (80, 0.0), (81, 0.0), (83, 0.0), (85, 0.0), (89, 0.0)]), StepLog(t=1, state=(97, 181, 113, 151, 0, 1), action=147, reward=0.5, next_state=(38, 163, 151, 206, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 20883}, q_values=[(145, 0.0), (146, 0.0), (147, 0.0), (157, 0.0), (158, 0.0), (159, 0.0), (161, 0.0), (162, 0.0), (163, 0.0), (173, 0.0), (174, 0.0), (175, 0.0), (181, 0.0), (182, 0.0), (183, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(109, 51, 76, 127, 0, 0), action=120, reward=0.0, next_state=(109, 51, 76, 127, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(72, 0.0), (73, 0.0), (96, 0.0), (97, 0.0), (108, 0.0), (109, 0.0), (120, 0.0), (121, 0.0)]), StepLog(t=1, state=(109, 51, 76, 127, 0, 1), action=None, reward=0.0, next_state=(109, 51, 76, 127, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(247, 0, 132, 218, 0, 0), action=243, reward=0.0, next_state=(247, 0, 132, 218, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(230, 0.0), (231, 0.0), (242, 0.0), (243, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(247, 0, 132, 218, 0, 1), action=None, reward=0.0, next_state=(247, 0, 132, 218, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(96, 144, 68, 229, 0, 0), action=96, reward=0.0, next_state=(96, 144, 68, 229, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(96, 0.0), (100, 0.0), (101, 0.0), (102, 0.0)]), StepLog(t=1, state=(96, 144, 68, 229, 0, 1), action=244, reward=0.5, next_state=(232, 193, 115, 97, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 24820}, q_values=[(244, 0.0), (245, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(152, 144, 143, 67, 0, 0), action=150, reward=0.0, next_state=(152, 144, 143, 67, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(142, 0.0), (143, 0.0), (150, 0.0), (151, 0.0)]), StepLog(t=1, state=(152, 144, 143, 67, 0, 1), action=None, reward=0.0, next_state=(152, 144, 143, 67, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(211, 150, 198, 178, 0, 0), action=148, reward=0.0, next_state=(211, 150, 198, 178, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(146, 0.0), (147, 0.0), (148, 0.0), (149, 0.0)]), StepLog(t=1, state=(211, 150, 198, 178, 0, 1), action=165, reward=0.5, next_state=(75, 41, 142, 110, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 38053}, q_values=[(146, 0.0), (147, 0.0), (148, 0.0), (149, 0.0), (150, 0.0), (162, 0.0), (163, 0.0), (164, 0.0), (165, 0.0), (166, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(99, 92, 93, 74, 0, 0), action=127, reward=0.0, next_state=(99, 92, 93, 74, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(125, 0.0), (126, 0.0), (127, 0.0)]), StepLog(t=1, state=(99, 92, 93, 74, 0, 1), action=79, reward=0.5, next_state=(158, 254, 10, 102, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 32591}, q_values=[(76, 0.0), (78, 0.0), (79, 0.0), (84, 0.0), (86, 0.0), (87, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(216, 234, 138, 147, 0, 0), action=200, reward=0.0, next_state=(216, 234, 138, 147, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(200, 0.0), (202, 0.0), (203, 0.0), (208, 0.0), (210, 0.0), (211, 0.0)]), StepLog(t=1, state=(216, 234, 138, 147, 0, 1), action=242, reward=0.5, next_state=(229, 145, 226, 188, 0, 0), done=False, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 51442}, q_values=[(242, 0.0), (243, 0.0), (248, 0.0), (249, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=2, state=(229, 145, 226, 188, 0, 0), action=134, reward=0.0, next_state=(229, 145, 226, 188, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(134, 0.0), (135, 0.0), (230, 0.0), (231, 0.0)]), StepLog(t=3, state=(229, 145, 226, 188, 0, 1), action=156, reward=0.5, next_state=(57, 13, 12, 111, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 34460}, q_values=[(156, 0.0), (157, 0.0), (172, 0.0), (173, 0.0)])], return_=1.0),
#  PathLog(steps=[StepLog(t=0, state=(235, 164, 178, 179, 0, 0), action=184, reward=0.0, next_state=(235, 164, 178, 179, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(178, 0.0), (179, 0.0), (184, 0.0), (185, 0.0), (190, 0.0), (191, 0.0), (210, 0.0), (211, 0.0), (216, 0.0), (217, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(235, 164, 178, 179, 0, 1), action=246, reward=0.5, next_state=(237, 113, 114, 56, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 47350}, q_values=[(150, 0.0), (151, 0.0), (246, 0.0), (247, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(147, 121, 237, 98, 0, 0), action=255, reward=0.0, next_state=(147, 121, 237, 98, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(253, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(147, 121, 237, 98, 0, 1), action=90, reward=0.5, next_state=(181, 254, 74, 209, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 65370}, q_values=[(90, 0.0), (91, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(182, 151, 233, 180, 0, 0), action=190, reward=0.0, next_state=(182, 151, 233, 180, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(190, 0.0), (191, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(182, 151, 233, 180, 0, 1), action=146, reward=0.5, next_state=(37, 125, 24, 65, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 48786}, q_values=[(146, 0.0), (147, 0.0), (158, 0.0), (159, 0.0), (162, 0.0), (163, 0.0), (174, 0.0), (175, 0.0), (182, 0.0), (183, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(244, 33, 193, 45, 0, 0), action=180, reward=0.0, next_state=(244, 33, 193, 45, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(180, 0.0), (181, 0.0)]), StepLog(t=1, state=(244, 33, 193, 45, 0, 1), action=45, reward=0.5, next_state=(91, 104, 176, 154, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 46125}, q_values=[(41, 0.0), (44, 0.0), (45, 0.0), (47, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(160, 128, 164, 186, 0, 0), action=133, reward=0.0, next_state=(160, 128, 164, 186, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(128, 0.0), (132, 0.0), (133, 0.0), (134, 0.0), (224, 0.0), (228, 0.0), (229, 0.0), (230, 0.0)]), StepLog(t=1, state=(160, 128, 164, 186, 0, 1), action=187, reward=0.5, next_state=(119, 11, 23, 81, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 34235}, q_values=[(184, 0.0), (186, 0.0), (187, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(92, 186, 95, 24, 0, 0), action=67, reward=0.0, next_state=(92, 186, 95, 24, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(66, 0.0), (67, 0.0), (78, 0.0), (79, 0.0), (90, 0.0), (91, 0.0), (114, 0.0), (115, 0.0), (126, 0.0), (127, 0.0)]), StepLog(t=1, state=(92, 186, 95, 24, 0, 1), action=None, reward=0.0, next_state=(92, 186, 95, 24, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(148, 25, 162, 167, 0, 0), action=183, reward=0.0, next_state=(148, 25, 162, 167, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(180, 0.0), (182, 0.0), (183, 0.0)]), StepLog(t=1, state=(148, 25, 162, 167, 0, 1), action=None, reward=0.0, next_state=(148, 25, 162, 167, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(158, 235, 151, 31, 0, 0), action=222, reward=0.0, next_state=(158, 235, 151, 31, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(132, 0.0), (133, 0.0), (136, 0.0), (137, 0.0), (142, 0.0), (143, 0.0), (180, 0.0), (181, 0.0), (184, 0.0), (185, 0.0), (190, 0.0), (191, 0.0), (212, 0.0), (213, 0.0), (216, 0.0), (217, 0.0), (222, 0.0), (223, 0.0)]), StepLog(t=1, state=(158, 235, 151, 31, 0, 1), action=None, reward=0.0, next_state=(158, 235, 151, 31, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(165, 86, 244, 86, 0, 0), action=196, reward=0.0, next_state=(165, 86, 244, 86, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(164, 0.0), (165, 0.0), (176, 0.0), (177, 0.0), (188, 0.0), (189, 0.0), (196, 0.0), (197, 0.0), (208, 0.0), (209, 0.0), (220, 0.0), (221, 0.0)]), StepLog(t=1, state=(165, 86, 244, 86, 0, 1), action=77, reward=0.5, next_state=(155, 136, 21, 22, 0, 0), done=True, info={'cw_round': 0, 'bias_round': 0.5, 'w16': 50253}, q_values=[(64, 0.0), (65, 0.0), (66, 0.0), (70, 0.0), (71, 0.0), (76, 0.0), (77, 0.0), (78, 0.0), (84, 0.0), (85, 0.0), (86, 0.0), (112, 0.0), (113, 0.0), (114, 0.0), (118, 0.0), (119, 0.0), (124, 0.0), (125, 0.0), (126, 0.0)])], return_=0.5),
#  PathLog(steps=[StepLog(t=0, state=(238, 94, 241, 170, 0, 0), action=158, reward=0.0, next_state=(238, 94, 241, 170, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(158, 0.0), (159, 0.0), (254, 0.0), (255, 0.0)]), StepLog(t=1, state=(238, 94, 241, 170, 0, 1), action=None, reward=0.0, next_state=(238, 94, 241, 170, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0),
#  PathLog(steps=[StepLog(t=0, state=(209, 23, 239, 146, 0, 0), action=189, reward=0.0, next_state=(209, 23, 239, 146, 0, 1), done=False, info={'phase': 'lo'}, q_values=[(189, 0.0), (190, 0.0), (191, 0.0)]), StepLog(t=1, state=(209, 23, 239, 146, 0, 1), action=None, reward=0.0, next_state=(209, 23, 239, 146, 0, 1), done=True, info={'note': 'no_actions'}, q_values=None)], return_=0.0)]

# %% [markdown]
# ## Key Recovery Matsui 2

# %%
from dataclasses import dataclass
from typing import List, Optional, Tuple, Any, Dict
import numpy as np

# %% [markdown]
# ### Utilities

# %%
def rol(x, r, w):
    mask = (1 << w) - 1
    x = x.astype(np.uint16) if isinstance(x, np.ndarray) else int(x)
    return ((x << r) & mask) | (x >> (w - r))

def ror(x, r, w):
    mask = (1 << w) - 1
    x = x.astype(np.uint16) if isinstance(x, np.ndarray) else int(x)
    return (x >> r) | ((x << (w - r)) & mask)

def parity16_np(a: np.ndarray) -> np.ndarray:
    """popcount mod 2 para uint16 (vectorizado). Retorna uint8 0/1."""
    x = a.astype(np.uint16)
    x ^= (x >> 8)
    x ^= (x >> 4)
    x ^= (x >> 2)
    x ^= (x >> 1)
    return (x & 1).astype(np.uint8)

def lin_eval_np(mask: int, x: np.ndarray) -> np.ndarray:
    """parity(mask & x) para arrays uint16."""
    return parity16_np(np.bitwise_and(x.astype(np.uint16), np.uint16(mask)))

# %% [markdown]
# ### Speck: inv 1 round

# %%
def speck_inv_round_np(c0: np.ndarray, c1: np.ndarray, k: int, w: int, alpha: int, beta: int) -> Tuple[np.ndarray, np.ndarray]:
    """
    Inversa de 1 ronda de SPECK (vectorizada):
      y ^= x; y = ROR(y, beta)
      x ^= k; x = (x - y) mod 2^w; x = ROL(x, alpha)
    """
    mask = (1 << w) - 1
    x = c0.astype(np.uint16)
    y = c1.astype(np.uint16)

    y = np.bitwise_xor(y, x)
    y = ror(y, beta, w).astype(np.uint16)

    x = np.bitwise_xor(x, np.uint16(k))
    x = (x - y) & np.uint16(mask)
    x = rol(x, alpha, w).astype(np.uint16)
    return x, y

# %% [markdown]
# ### Linear approximiation class

# %%
@dataclass(frozen=True)
class LinearApprox:
    """
    parity(a0&p0) ^ parity(a1&p1) ^ parity(b0&x_prev) ^ parity(b1&y_prev) ^ const == 0
    donde (x_prev, y_prev) = estado antes de la última ronda (desencriptado parcial).
    """
    a0: int
    a1: int
    b0: int
    b1: int
    const: int = 0
    sign: Optional[int] = None
    weight: float = 1.0

# %% [markdown]
# ### More Utilities

# %%
def make_encrypt_adapter(speck_obj):
    """
    Adaptador robusto: crea una función encrypt(p0_arr, p1_arr)->(c0_arr,c1_arr).
    """
    def encrypt_fn(p0: np.ndarray, p1: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
        c0 = np.empty_like(p0, dtype=np.uint16)
        c1 = np.empty_like(p1, dtype=np.uint16)

        # Intento 1: método encrypt((x,y)) -> (X,Y)
        if hasattr(speck_obj, "encrypt"):
            enc = speck_obj.encrypt
            for i in range(p0.size):
                X, Y = enc((int(p0[i]), int(p1[i])))
                c0[i] = np.uint16(X)
                c1[i] = np.uint16(Y)
            return c0, c1

        raise AttributeError("No encontré speck_obj.encrypt. Ajusta make_encrypt_adapter a tu API real.")
    return encrypt_fn


def generate_pairs(encrypt_fn, n: int, w: int = 16, seed: int = 2025):
    rng = np.random.default_rng(seed)
    p0 = rng.integers(0, 1 << w, size=n, dtype=np.uint16)
    p1 = rng.integers(0, 1 << w, size=n, dtype=np.uint16)
    c0, c1 = encrypt_fn(p0, p1)
    return p0, p1, c0, c1

# %% [markdown]
# ### Lectura de paths

# %%
def _get_attr(obj, name: str, default=None):
    return getattr(obj, name, default)

def combine_hi_lo_to_mask16(hi: int, lo: int, half_bits: int = 8) -> int:
    return ((int(hi) & ((1 << half_bits) - 1)) << half_bits) | (int(lo) & ((1 << half_bits) - 1))

def masks16_from_state_hilo(state6, half_bits: int = 8):
    """
    state=(hi0, hi1, lo0, lo1, round_idx, phase_flag)
    -> (m0, m1, round_idx, phase_flag)
    """
    hi0, hi1, lo0, lo1, r_idx, ph = state6
    m0 = combine_hi_lo_to_mask16(hi0, lo0, half_bits=half_bits)
    m1 = combine_hi_lo_to_mask16(hi1, lo1, half_bits=half_bits)
    return m0, m1, int(r_idx), int(ph)

def get_steps_from_path(pathlog) -> List[Any]:
    steps = _get_attr(pathlog, "steps", None)
    if steps is None and isinstance(pathlog, dict):
        steps = pathlog.get("steps", None)
    if steps is None:
        raise ValueError("No pude leer path.steps")
    return list(steps)

def last_step(pathlog):
    steps = get_steps_from_path(pathlog)
    return steps[-1]

def extract_trail_masks_from_path(pathlog, half_bits: int = 8):
    """
    Ignorando dead_end: toma siempre:
      a0,a1 = máscaras del primer step.state
      b0,b1 = máscaras del último step.state
    """
    steps = get_steps_from_path(pathlog)
    first = steps[0]
    last  = steps[-1]

    a0, a1, r0, ph0 = masks16_from_state_hilo(_get_attr(first, "state"), half_bits=half_bits)
    b0, b1, rL, phL = masks16_from_state_hilo(_get_attr(last,  "state"), half_bits=half_bits)

    meta = {
        "r0": r0, "ph0": ph0,
        "r_last": rL, "ph_last": phL,
        "return_": _get_attr(pathlog, "return_", None),
        "last_info": _get_attr(last, "info", None),
    }
    return (a0, a1, b0, b1, meta)

def linear_approx_from_path(pathlog, weight: float = 1.0, sign=None, const: int = 0, half_bits: int = 8):
    a0, a1, b0, b1, meta = extract_trail_masks_from_path(pathlog, half_bits=half_bits)
    app = LinearApprox(a0=a0, a1=a1, b0=b0, b1=b1, const=const, sign=sign, weight=weight)
    return app, meta

# %% [markdown]
# ### Code for the attack

# %%
def matsui2_recover_last_round_key(
    p0: np.ndarray,
    p1: np.ndarray,
    c0: np.ndarray,
    c1: np.ndarray,
    approximations: List[LinearApprox],
    w: int = 16,
    alpha: int = 7,
    beta: int = 2,
    guess_bits: int = 12,
    top_k: int = 10,
    return_all: bool = False,
):
    """
    Recupera guess de subkey final por Matsui 2 (sesgo).
    Se adivinan los guess_bits LSB del subkey.
    Score = suma over trails de:
      weight * (abs(bias) si sign=None else sign*bias)
    donde bias = count(z==0) - N/2
    """
    assert p0.dtype == np.uint16 and p1.dtype == np.uint16 and c0.dtype == np.uint16 and c1.dtype == np.uint16
    n = p0.size
    half = n / 2.0

    scores = np.zeros(1 << guess_bits, dtype=np.float64)

    # Precalcula términos de plaintext por trail (independiente de k)
    pt_terms = []
    for app in approximations:
        t = lin_eval_np(app.a0, p0) ^ lin_eval_np(app.a1, p1)
        if app.const & 1:
            t ^= 1
        pt_terms.append(t.astype(np.uint8))

    # Loop de guesses
    for g in range(1 << guess_bits):
        k = int(g)  # LSB guess
        x_prev, y_prev = speck_inv_round_np(c0, c1, k, w=w, alpha=alpha, beta=beta)

        total = 0.0
        for idx, app in enumerate(approximations):
            z = pt_terms[idx] ^ lin_eval_np(app.b0, x_prev) ^ lin_eval_np(app.b1, y_prev)
            cnt0 = float(np.sum(z == 0))
            bias = cnt0 - half

            if app.sign is None:
                contrib = app.weight * abs(bias)
            else:
                contrib = app.weight * (app.sign * bias)

            total += contrib

        scores[g] = total

    best_idx = np.argsort(scores)[::-1][:top_k]
    best = [(int(i), float(scores[i])) for i in best_idx]
    return (best, scores) if return_all else best



def matsui2_from_paths(
    paths: List[Any],
    p0: np.ndarray,
    p1: np.ndarray,
    c0: np.ndarray,
    c1: np.ndarray,
    guess_bits: int = 12,
    top_k: int = 10,
    alpha: int = 7,
    beta: int = 2,
    half_bits: int = 8,
    default_weight: float = 1.0,
    return_meta: bool = True,
):
    approximations: List[LinearApprox] = []
    meta_rows: List[Dict[str, Any]] = []

    for path in paths:
        app, meta = linear_approx_from_path(
            path,
            weight=default_weight,
            sign=None,
            const=0,
            half_bits=half_bits
        )
        approximations.append(app)
        meta_rows.append(meta)

    best = matsui2_recover_last_round_key(
        p0, p1, c0, c1,
        approximations=approximations,
        w=16, alpha=alpha, beta=beta,
        guess_bits=guess_bits,
        top_k=top_k,
        return_all=False
    )

    if return_meta:
        return best, approximations, meta_rows
    return best

# %%
encrypt_fn = make_encrypt_adapter(speck)
p0, p1, c0, c1 = generate_pairs(encrypt_fn, n=1<<14, w=16, seed=2025)

# %% [markdown]
# ### Helpers

# %%
def mask_bit_positions(mask: int, word_size: int = 16):
    return [i for i in range(word_size) if (mask >> i) & 1]

def expand_compact_guess(g: int, bitpos: list):
    kg = 0
    for j, b in enumerate(bitpos):
        if (g >> j) & 1:
            kg |= (1 << b)
    return kg

def gen_key_guesses_from_mask_EXPANDED(w_last: int, word_size: int = 16):
    bitpos = mask_bit_positions(int(w_last), word_size=word_size)
    kbits = len(bitpos)
    for g in range(1 << kbits):
        yield expand_compact_guess(g, bitpos)

# %%
# --- sanity check del generador ---
w = 0x8b67
bps = mask_bit_positions(w, 16)
print("w_last:", hex(w), "bits:", bps)

for i, kg in zip(range(10), gen_key_guesses_from_mask_EXPANDED(w, 16)):
    print(i, hex(kg), "masked:", hex(kg & w))
# Out:
# w_last: 0x8b67 bits: [0, 1, 2, 5, 6, 8, 9, 11, 15]
# 0 0x0 masked: 0x0
# 1 0x1 masked: 0x1
# 2 0x2 masked: 0x2
# 3 0x3 masked: 0x3
# 4 0x4 masked: 0x4
# 5 0x5 masked: 0x5
# 6 0x6 masked: 0x6
# 7 0x7 masked: 0x7
# 8 0x20 masked: 0x20
# 9 0x21 masked: 0x21

# %%
best, apps, metas = matsui2_from_paths(
    paths=paths_validos,
    p0=p0, p1=p1, c0=c0, c1=c1,
    guess_bits=12,
    top_k=10,
    alpha=7, beta=2,
    half_bits=8,
    default_weight=1.0,
    return_meta=True
)

print("Top guesses:", best)
print("Ejemplo app[0]:", apps[0])
print("Meta[0]:", metas[0])
# Out:
# Top guesses: [(1777, 20726.0), (4064, 20473.0), (368, 20313.0), (1468, 20092.0), (2656, 20077.0), (102, 20057.0), (3808, 19975.0), (1800, 19901.0), (2416, 19871.0), (1465, 19853.0)]
# Ejemplo app[0]: LinearApprox(a0=5393, a1=12990, b0=5393, b1=12990, const=0, sign=None, weight=1.0)
# Meta[0]: {'r0': 0, 'ph0': 0, 'r_last': 0, 'ph_last': 1, 'return_': 0.0, 'last_info': {'note': 'no_actions'}}

# %%
def matsui2_last_round_rank_vec(
    p0: np.ndarray,
    p1: np.ndarray,
    xR: np.ndarray,
    yR: np.ndarray,
    ax0: int,
    ay0: int,          # máscaras en plaintext (origen del path)
    ax: int,
    ay: int,           # máscaras en la ENTRADA a última ronda (x_{R-1}, y_{R-1})
    w_last: int,
    alpha: int,
    beta: int,
    debug: bool = False,
    debug_once: bool = True,
    _dbg_state: dict | None = None,
):
    """
    Matsui-2 (sesgo) usando partial-decrypt de la ÚLTIMA ronda.
    Score(k) = | sum(1 - 2*lhs) | donde
      lhs = <ax0,p0> ^ <ay0,p1> ^ <ax,x_prev(k)> ^ <ay,y_prev(k)>
    """
    if _dbg_state is None:
        _dbg_state = {"printed": False}

    # guesses expandidos a posiciones reales de w_last
    all_guesses = list(gen_key_guesses_from_mask_EXPANDED(int(w_last), word_size=16))
    if not all_guesses:
        return []

    # parte constante (plaintext), independiente de k
    px0 = parity_mask_arr(p0, ax0)
    py0 = parity_mask_arr(p1, ay0)

    # helper para tests
    def score_key(k_guess: int) -> int:
        y = ror16(np.uint16(yR ^ xR), beta)
        x = np.uint16(xR ^ np.uint16(k_guess))
        x = np.uint16((x - y) & 0xFFFF)
        x = rol16(x, alpha)
        lhs = px0 ^ py0 ^ parity_mask_arr(x, ax) ^ parity_mask_arr(y, ay)
        return int(np.abs(np.sum(1 - 2 * lhs.astype(np.int32))))

    # ¿imprimir debug?
    do_print = debug and (not debug_once or not _dbg_state["printed"])

    if do_print:
        print("DEBUG w_last:", hex(int(w_last)))
        print("DEBUG any bit15 in guesses?", any((kg & 0x8000) for kg in all_guesses))
        print("DEBUG max(guesses):", hex(max(all_guesses)))

        s0 = score_key(0x0000)
        s1 = score_key(0x8000)
        print("DEBUG score(0x0000):", s0, "score(0x8000):", s1, "diff:", (s1 - s0))

    ranked = []
    for kg in all_guesses:
        # Inversa de 1 ronda
        y = ror16(np.uint16(yR ^ xR), beta)
        x = np.uint16(xR ^ np.uint16(kg))
        x = np.uint16((x - y) & 0xFFFF)
        x = rol16(x, alpha)

        lhs = px0 ^ py0 ^ parity_mask_arr(x, ax) ^ parity_mask_arr(y, ay)
        score = int(np.abs(np.sum(1 - 2 * lhs.astype(np.int32))))
        ranked.append((int(kg), score))

    # Test de empates / scores
    if do_print:
        scores = np.array([sc for _, sc in ranked], dtype=np.int64)
        top = int(scores.max())
        ties_top = int((scores == top).sum())
        uniq = int(np.unique(scores).size)
        print("DEBUG top score:", top, "| ties at top:", ties_top, "of", len(scores), "| unique scores:", uniq)

        top_keys = [kg for kg, sc in ranked if sc == top]
        if top_keys:
            frac_top_bit15 = float(np.mean([(k & 0x8000) != 0 for k in top_keys]))
            print("DEBUG frac(bit15=1 among top-ties):", frac_top_bit15)

        _dbg_state["printed"] = True

    # IMPORTANT: desempate para evitar sesgo hacia claves pequeñas cuando score empata
    ranked.sort(key=lambda kv: (kv[1], kv[0]), reverse=True)
    return ranked


def run_key_recovery_for_paths_matsui2(
    paths: list,
    speck_obj,
    R: int,
    n_pairs: int = 1 << 14,
    trials_per_path: int = 50,
    top_k: int = 5,
    max_guess_bits: int = 10,
    seed: int = 2025,
    debug: bool = False
):
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt

    def error_bit_positions_masked(k_guess: int, k_true: int, w_mask: int, word_size: int = 16):
        diff = (k_guess ^ k_true) & w_mask
        return [i for i in range(word_size) if (diff >> i) & 1]

    def first_round_masks_from_path(path):
        if path is None or not getattr(path, "steps", None):
            return None, None
        st0 = path.steps[0].state
        ax0, ay0 = state_to_masks(st0, word_size=speck_obj.word_size)
        return int(ax0), int(ay0)

    def add_hex_columns(df, cols, word_size):
        mask = (1 << word_size) - 1
        for c in cols:
            if c in df.columns:
                df[c + "_hex"] = df[c].apply(
                    lambda v: None if pd.isna(v) else f"0x{(int(v) & mask):0{word_size//4}x}"
                )

    rng = np.random.default_rng(seed)
    rows = []
    err_rows = []

    FULL_MASK = (1 << speck_obj.word_size) - 1

    df_results = pd.DataFrame()
    df_errors = pd.DataFrame()

    # para imprimir debug SOLO una vez en toda la corrida
    dbg_state = {"printed": False}

    try:
        for pi, path in enumerate(paths):
            masks = last_round_masks_from_path(path, R=R, word_size=speck_obj.word_size)
            if masks is None:
                continue

            ax0, ay0 = first_round_masks_from_path(path)

            ax, ay, gx, gy, w_last = masks
            w_last = int(w_last) & FULL_MASK
            kbits = popcount(w_last)

            if kbits == 0 or kbits > max_guess_bits:
                continue

            for t in range(trials_per_path):
                # --- key random ---
                key_words = [
                    int(rng.integers(0, 1 << speck_obj.word_size, dtype=np.uint16))
                    for _ in range(speck_obj.n_main_key_words)
                ]
                rk = speck_obj.key_schedule(key_words)
                rk_u16 = np.array([int(rk[i][0]) for i in range(R)], dtype=np.uint16)
                true_last = int(rk_u16[-1]) & FULL_MASK

                # --- pares P/C ---
                x0p = rng.integers(0, 1 << speck_obj.word_size, size=n_pairs, dtype=np.uint16)
                y0p = rng.integers(0, 1 << speck_obj.word_size, size=n_pairs, dtype=np.uint16)
                xR, yR = speck_encrypt_vec(x0p, y0p, rk_u16, alpha=speck_obj.alpha, beta=speck_obj.beta)

                ranked = matsui2_last_round_rank_vec(
                    p0=x0p, p1=y0p,
                    xR=xR, yR=yR,
                    ax0=int(ax0) if ax0 is not None else 0,
                    ay0=int(ay0) if ay0 is not None else 0,
                    ax=int(ax), ay=int(ay),
                    w_last=int(w_last),
                    alpha=speck_obj.alpha, beta=speck_obj.beta,
                    debug=debug,
                    debug_once=True,
                    _dbg_state=dbg_state
                )

                if not ranked:
                    continue

                true_partial = true_last & w_last

                best_guess = int(ranked[0][0]) & FULL_MASK
                bit_errors_top1 = int(hamming_masked(best_guess, true_last, w_last))
                success_top1 = (bit_errors_top1 == 0)

                rank_true = None
                for i, (kg, sc) in enumerate(ranked):
                    if (int(kg) & w_last) == true_partial:
                        rank_true = i + 1
                        break

                success_topk = (rank_true is not None and rank_true <= top_k)

                error_mask = int((best_guess ^ true_last) & w_last)
                error_positions = error_bit_positions_masked(
                    best_guess, true_last, w_last, word_size=speck_obj.word_size
                )

                rows.append({
                    "path_idx": int(pi),
                    "trial": int(t),

                    "ax0": ax0, "ay0": ay0,
                    "ax": int(ax), "ay": int(ay),
                    "gx": int(gx), "gy": int(gy),

                    "w_last": int(w_last),
                    "guess_bits": int(kbits),
                    "n_pairs": int(n_pairs),

                    "true_last": int(true_last),
                    "best_guess": int(best_guess),

                    "bit_errors_top1": int(bit_errors_top1),
                    "success_top1": bool(success_top1),

                    "rank_true": rank_true,
                    "success_topk": bool(success_topk),
                })

                if not success_top1:
                    err_rows.append({
                        "path_idx": int(pi),
                        "trial": int(t),

                        "ax0": ax0, "ay0": ay0,
                        "ax": int(ax), "ay": int(ay),

                        "w_last": int(w_last),
                        "guess_bits": int(kbits),

                        "true_last": int(true_last),
                        "best_guess": int(best_guess),

                        "bit_errors_top1": int(bit_errors_top1),
                        "error_mask": error_mask,
                        "error_positions": error_positions,
                    })

        df_results = pd.DataFrame(rows)
        df_errors = pd.DataFrame(err_rows)

        if df_results.empty:
            print("No salió ningún experimento (revisa paths, R, o baja max_guess_bits / sube n_pairs).")
            return df_results, df_errors

        add_hex_columns(
            df_results,
            cols=["ax0", "ay0", "ax", "ay", "gx", "gy", "w_last", "true_last", "best_guess"],
            word_size=speck_obj.word_size
        )
        add_hex_columns(
            df_errors,
            cols=["ax0", "ay0", "ax", "ay", "w_last", "true_last", "best_guess", "error_mask"],
            word_size=speck_obj.word_size
        )

        total = len(df_results)
        s1 = int(df_results["success_top1"].sum())
        sk = int(df_results["success_topk"].sum())

        print(f"Experimentos: {total}")
        print(f"Aciertos top-1: {s1}  ({100*s1/total:.2f}%)")
        print(f"Aciertos top-{top_k}: {sk} ({100*sk/total:.2f}%)")

        for thr in [1, 2, 3]:
            frac = float((df_results["bit_errors_top1"] <= thr).mean())
            print(f"Top-1 con <={thr} bit(s) mal: {int(frac*total)} ({100*frac:.2f}%)")

        misses = df_results[~df_results["success_top1"]]
        if not misses.empty:
            dist = misses["bit_errors_top1"].value_counts().sort_index()
            print("\nDesaciertos (top-1) - distribución de bits equivocados (solo en w_last):")
            print(dist)

            dist.plot(kind="bar")
            plt.xlabel("# bits equivocados (en w_last)")
            plt.ylabel("conteo")
            plt.title("Distribución de errores en desaciertos (top-1)")
            plt.tight_layout()
            plt.show()

        return df_results, df_errors

    except Exception as e:
        print(f"An unexpected error occurred during processing results: {e}")
        return df_results, df_errors

# %%
df_results_2, df_errors_2 = run_key_recovery_for_paths_matsui2(paths_validos, speck, env.R)
# Out:
# No salió ningún experimento (revisa paths, R, o baja max_guess_bits / sube n_pairs).

# %%
df_results, df_errors = run_key_recovery_for_paths_matsui2(paths_validos, speck, env.R, debug=True)
# Out:
# No salió ningún experimento (revisa paths, R, o baja max_guess_bits / sube n_pairs).

# %%
df_results_2.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_errors.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
